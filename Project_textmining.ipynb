# %% [markdown]
# # **Sec-Filings**
#
# The dataset presented in this work combines the CoNLL-2003 data with financial documents sourced from U.S. Securities and Exchange Commission (SEC) filings.
#
# The CoNLL-2003 dataset consists of eight text files annotated with named entities. The entities are divided into four main categories: persons, organizations, locations and miscellaneous entities. Each token in the dataset is labeled with its corresponding entity type, providing a labeled corpus for training and evaluating Named Entity Recognition (NER) model.
#
# The dataset is divided into two subsets (*train* and *test* datasets) and each of them has four columns:
#
# - `id` : tokens
# - `chunk_label`: classification label for named entity
# - `-`: empty column
# - `ner_tags`: classification label for named entity
#
# The `chunk_label` column contains for each token a fine-grained tag as determined by morphology (e.g., NNP for a singular proper noun, VBD for a past tense verbe, etc.).
#
# There are five different types of `ner_tags` in the dataset:

# %% [markdown]
# <table><tr><th>NER</th><th>DESCRIPTION</th><th>EXAMPLES</th></tr>
#
# <tr><td>O</td><td>Token that belongs to no chunk</td><td>loan, security, agreement</td></tr>
# <tr><td>I-LOC</td><td>Token representing a location</td><td>California, Massachusetts</td></tr>
# <tr><td>I-PER</td><td>Token representing a person</td><td>Bing, Yu</td></tr>
# <tr><td>I-ORG</td><td>Token representin an organization</td><td>Silicon Valley Bank</td></tr>
# <tr><td>I-MISC</td><td>Token with no specific category</td><td>Chinese, English</td></tr>

# %% [markdown]
# The aim of this paper is to build a model that is able to correctly predict the `ner_tag` of each token. Since the dataset already contains the appropriate tag, some supervised learning algorithms will be implemented. They receive a set of inputs along with the corresponding correct outputs and learn by comparing their actual outputs with the correct ones to find errors.
#
#
# The training dataset, consisting of 42182 observations, is cleaned and prepared to be used in different tasks. An exploratory analysis is then performed and the key findings are then exhibited using data visualization techniques.

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
df = pd.read_csv('/content/drive/MyDrive/FIN5.csv', sep = ';')
df.columns = ['id', 'chunk_label', 'empty', 'ner_tags']
df = df.drop(0)
df.head()
# Out:
#           id chunk_label empty ner_tags
# 1       This          DT     -        O
# 2       LOAN          NN     -        O
# 3        AND          CC     -        O
# 4   SECURITY         NNP     -        O
# 5  AGREEMENT         NNP     -        O

# %% [markdown]
# The first five rows of the dataset are represented by way of example in the table above.

# %% [markdown]
# # Data preparation and cleaning

# %% [markdown]
# For consistency, ensure that all column labels are of type string.

# %%
all(isinstance(column, str) for column in df.columns)
# Out:
# True

# %% [markdown]
# Once checked for the existence of missing values, 1167 observations are removed from the dataset.

# %%
df.isnull().sum()
# Out:
# id             1167
# chunk_label    1167
# empty          1167
# ner_tags       1167
# dtype: int64

# %%
df = df.dropna()

len(df)
# Out:
# 41014

# %%
df.isnull().sum()
# Out:
# id             0
# chunk_label    0
# empty          0
# ner_tags       0
# dtype: int64

# %% [markdown]
# Then, empty strings have been detected and removed, in order not to have blank cells.

# %%
blanks = []

# (index,id,chunk_label,empty,ner_tags)
for index,id,chunk_label,empty,ner_tags in df.itertuples():  # iterate over the DataFrame
    if type(id)==str:                                        # avoid NaN values
        if id.isspace():                                     # test 'review' for whitespace
            blanks.append(index)                             # add matching index numbers to the list

blanks
# Out:
# []

# %% [markdown]
# Empty columns are dropped as well.

# %%
df.drop("empty", axis = 'columns', inplace = True)

df
# Out:
#               id chunk_label ner_tags
# 1           This          DT        O
# 2           LOAN          NN        O
# 3            AND          CC        O
# 4       SECURITY         NNP        O
# 5      AGREEMENT         NNP        O
# ...          ...         ...      ...
# 42177          /          NN        O
# 42178          s         NNS        O
# 42179          /           :        O
# 42180       Bing         VBG    I-PER
# 42181         Yu         NNP    I-PER
#
# [41014 rows x 3 columns]

# %% [markdown]
# The number of tokens corresponding to the 10 most frequent `chunk_label` is:

# %%
df['chunk_label'].value_counts()[:10]
# Out:
# NNP    6067
# NN     5617
# IN     4772
# DT     4215
# NNS    2308
# CC     2300
# ,      2075
# JJ     1903
# CD     1488
# :      1400
# Name: chunk_label, dtype: int64

# %% [markdown]
# As reasonably expected, the most frequent ones are those related to nouns, conjunctions, determiners and punctuation marks.

# %% [markdown]
# Instead, the frequency of the five `ner_tags` is:

# %%
df['ner_tags'].value_counts()
# Out:
# O         39484
# I-PER       783
# I-ORG       384
# I-LOC       356
# I-MISC        7
# Name: ner_tags, dtype: int64

# %% [markdown]
# The occurrences of the `ner_tag` **O** are significantly higher compared to all the others.
# \
# Here follows the visualization of the named entities of the corpus first sentence.

# %%
import spacy
from spacy import displacy # function used to see ner tags

tokens = df['id'][:104].tolist()
ner_tags=df['ner_tags'][:104].tolist()

doc = spacy.tokens.Doc(spacy.vocab.Vocab(), words=tokens) # doc è il documento di testo, che contiene la lista di token
entities = [] # inizializza una lista
for token, ner_tag in zip(doc, ner_tags):
    if ner_tag != "O":
        entities.append(spacy.tokens.Span(doc, token.i, token.i + 1, label=ner_tag))
# Aggiunge alla lista delle entità un oggetto Span, che rappresenta un intervallo di token che forma un'entità, con il ner_tag specificato
# span è un sottoinsieme di token all'interno di un documento di testo che forma un'entità

doc.ents = entities # Assegna la lista di entità al documento spaCy.

options = {"ents": ["I-ORG", "I-LOC", "I-PER"], "colors": {"I-ORG": "yellow", "I-LOC": "green", "I-PER": "pink"}}
displacy.render(doc, style='ent', jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">This LOAN AND SECURITY AGREEMENT dated January 27 , 1999 , between
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     SILICON
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     VALLEY
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     BANK
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  (&quot;
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  &quot;), a
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  - chartered
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     bank
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  with its principal place of business at
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     3003
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tasman
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Drive
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  ,
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Santa
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Clara
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  ,
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     California
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  95054 with a loan production office located at
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     40
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     William
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     St
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  ., Ste . 350 ,
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Wellesley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  ,
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Massachusetts
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  2481 doing business as &quot;
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Silicon
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Valley
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     East
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  &quot; and
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AKAMAI
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: yellow; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     TECHNOLOGIES
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  , INC . (&quot;
# <mark class="entity" style="background: pink; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Borrower
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-PER</span>
# </mark>
#  &quot;), whose address is
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     201
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#
# <mark class="entity" style="background: green; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Broadway
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-LOC</span>
# </mark>
#  , 4th Floor ,
# <mark class="entity" style="background: green; padding: 0.45em 0.6

# %% [markdown]
# Since raw text data might contain unwanted or unimportant
# text due to which results might not be efficient, the following lines of code perform several operations to clean the unstructered text:
#
#
# *   all the tokens in the `id` column are converted to lowercase to maintain a consistent flow during the NLP tasks and text mining;
# *   remove punctuation symbols and special characters since they do not provide additional information;
# *   remove numbers and stopwords (e.g., 'the', 'a', 'is') since they are the most frequently appearing words in any paragraph and they are not meaningless for sentences.

# %%
from wordcloud import STOPWORDS

stopwords = set(STOPWORDS)

# %%
df['id'] = df['id'].map(str.lower)

# remove special characters from -docstart- tokens to maintain the documents division
df['id'] = df['id'].str.replace('-docstart-', 'docstart')

# %%
removed = []

for index, id, chunk_label, ner_tags in df.itertuples():
  if id.isalnum() == False or id.isalpha() == False or id in stopwords or len(id) < 2:
    removed.append(index)

removed[:6]
# Out:
# [1, 3, 8, 9, 10, 11]

# %%
norm_df = df.drop(removed)

print(len(norm_df))
# Out:
# 17899

# %%
norm_df.index = range(1, 17900)

norm_df.head()
# Out:
#           id chunk_label ner_tags
# 1       loan          NN        O
# 2   security         NNP        O
# 3  agreement         NNP        O
# 4      dated         VBD        O
# 5    january         NNP        O

# %%
norm_df['ner_tags'].value_counts()
# Out:
# O         16439
# I-PER       777
# I-ORG       372
# I-LOC       304
# I-MISC        7
# Name: ner_tags, dtype: int64

# %% [markdown]
# The updated frequency of `ner_tags` can be observed, once again featuring a significantly higher count of **O**s in comparison to the other labels, indicating that the final dataset is really unbalanced.

# %% [markdown]
# # Data exploratory Analysis

# %% [markdown]
# ## Word Clouds

# %% [markdown]
# A word cloud is a visual representation of the words used in a text, with the size of each word indicating its relative frequency.
#
# The existing Python package *wordcloud* operates on a straightforward principle: the greater the frequency of a particular word in a text, the more significant and prominent it becomes in the word cloud.

# %%
from wordcloud import WordCloud

# %%
# create a list of tokens and join them together in a string
text = norm_df['id'].tolist()
doc = " ".join(text)

doc
# Out:
# 'loan security agreement dated january silicon valley bank bank california chartered bank principal place business tasman drive santa clara california loan production office located william st ste wellesley massachusetts business silicon valley east akamai technologies inc borrower whose address broadway floor cambridge massachusetts provides terms bank will lend borrower borrower will repay bank parties agree follows accounting terms accounting terms defined agreement will construed following gaap calculations determinations must made following gaap term financial statements includes notes schedules terms including includes always mean including includes without limitation loan document agreement construed impart upon bank duty act reasonably times loan terms payment credit extensions borrower will pay bank unpaid principal amount credit extensions interest unpaid principal amount credit extensions equipment facility subject terms conditions agreement bank agrees lend borrower time time prior commitment termination date equipment advances equipment advance collectively equipment advances prepaid principal equipment advances may re borrowed proceeds equipment advances will used solely reimburse borrower purchase eligible equipment equipment advance considered promissory note evidencing amounts due hereunder purposes bank obligation lend hereunder terminate earlier occurrence continuance event default ii commitment termination date purposes section minimum amount equipment advance maximum number equipment advances will made obtain equipment advance borrower will deliver bank completed supplement substantially form attached loan supplement together invoices additional information bank may request least five business days proposed funding date funding date funding date bank will specify loan supplement equipment advance basic rate loan factor payment dates table stipulated loan values together ucc financing statement covering equipment described loan supplement borrower satisfies conditions equipment advance specified time time bank bank will disburse equipment advance internal transfer borrower deposit account bank bank obligation lend undisbursed portion committed equipment line will terminate bank sole discretion material adverse change general affairs management results operation condition financial prospects borrower whether arising transactions ordinary course business material adverse deviation borrower recent business plan borrower presented accepted bank prior execution agreement page interest rate payments principal interest payments payment dates borrower will make payments monthly advance principal accrued interest equipment advance collectively scheduled payments first business day month following funding date commencing funding date funding date first business day month respect equipment advance continuing thereafter repayment period first business day calendar month payment date amount equal loan factor multiplied loan amount equipment advance payment date unpaid principal accrued interest due payable full last payment date respect equipment advance equipment advance may prepaid upon payment prepayment premium specified bank interest rate borrower will pay interest unpaid principal amount equipment advance first payment date funding date equipment advance equipment advance paid full per annum rate interest equal basic rate determined bank funding date equipment advance accordance definition basic rate basic rate funding date per annum rate interest based year days equal sum treasury note yield maturity term equal treasury note maturity quoted wall street journal day applicable loan terms schedule prepared plus applicable loan margin type eligible equipment financed loan margin basis points treasury note maturity months interim payment addition scheduled payments funding date equipment advance unless funding date first business day month borrower pay bank behalf bank amount interim payment equal initial equipment ad ...

# %%
# %%capture

sec_wc = WordCloud(
    background_color = 'white',
    max_words = 10000,
)

sec_wc.generate(doc)

# %% [markdown]
# Once the word cloud is created, it is possible to visualize it.

# %%
# %matplotlib inline

import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # needed for waffle Charts

mpl.style.use('ggplot') # optional: for ggplot-like style

# %%
fig = plt.figure(figsize=(14, 18))

# display the word cloud
plt.imshow(sec_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# In the first 10000 words, the most common ones in the text are: **Agreement**, **Borrower**, **Lender**, **Agent** and **Bank**.

# %% [markdown]
# ## Exploratory Language Statistics

# %% [markdown]
# The *N-gram analysis* is useful to extract meaningful information about language usage, identify key phrases and gain insights into the structure of textual data.

# %%
from collections import Counter # count the occurrences of each n-gram in the text

word_counts = Counter(text)

freqs = list(word_counts.values())

bigram_tokens = ['--'.join(pair) for pair in zip(text[:-1], text[1:])]
bigram_vocab = Counter(bigram_tokens)
bigram_freqs = list(bigram_vocab.values())

trigram_tokens = ['--'.join(triple) for triple in zip(text[:-2], text[1:-1], text[2:])]
trigram_vocab = Counter(trigram_tokens)
trigram_freqs = list(trigram_vocab.values())

freqs.sort(reverse = True)
bigram_freqs.sort(reverse = True)
trigram_freqs.sort(reverse = True)

# %% [markdown]
# The code above performs n-gram analysis, calculating the frequencies of individual words (*unigrams*), adjacent word pairs (*bigrams*) and consecutive word triplets (*trigrams*). It utilizes *Counter* from the *collections* module to count the occurrences of each n-gram in the text. The resulting frequency distributions are sorted in descending order to facilitate a rapid understanding of the distributions of the computed n-grams.

# %%
plt.plot(freqs, label='Unigrams', drawstyle='default')
plt.plot(bigram_freqs, label='Bigrams', drawstyle='default')
plt.plot(trigram_freqs, label='Trigrams', drawstyle='default')

plt.xlabel('token: x')
plt.ylabel('frequency: n(x)')
plt.legend()
plt.title('Logarithmic Frequencies of Unigrams, Bigrams, and Trigrams')
plt.xscale('log')
plt.yscale('log')

plt.show()

# %% [markdown]
# The logarithmic scale is employed in the plot to accommodate the wide range of frequencies, making it easier to visualize variations across different magnitudes.
# \
# Observe that the unigrams exhibit a more pronounced decay compared to bigrams and trigrams, as the more frequent ones have significantly higher frequencies, while the less frequent ones are fewer in number.

# %% [markdown]
# MAN MANO CHE CONSIDERO TOKEN MENO FREQUENTI, LA FREQUENZA DEGLI UNIGRAMS SCENDE PIU VELOCEMENTE PERCHè ESSI SONO MENO DEI BIGRAMS, I QUALI SONO MENO DEI TRIGRAMS (I TOKEN UNICI -> UNIGRAMS SONO 2845, LE PAROLE TOTALI SONO 18000)
#
# NB: GLI SCALINI SONO DATI DALLA SCALA LOGARITMICA -> NELLO STESSO INTERVALLO ABBIAMO GRANDEZZE ESPONENZIALMENTE DIVERSE (DA 1 A 1O E DA 100 A 1000 SONO RAPPRESENTATI CON LA STESSA DISTANZA) -> SE ZOOMASSIMO SU OGNI SINGOLO INTERVALLO, VEDREMMO UNA DECRESCITA PIU SMOOTH (DRITTA)

# %% [markdown]
# ## LDA

# %% [markdown]
# After detecting five *docstart* tokens, which are assumed to mark the boundaries between distinct documents within the whole corpus, a reasonable approach consists in applying the topic modelling technique, which allows to efficiently analyze large volumes of text by clustering documents into topics.
#
# Specifically, LDA (Latent Dirichlet Allocation) is the method used here and it is built on the assumption that documents with similar topics use similar groups of words. Then, documents can be intended as probability distributions over latent topics, which can be found by looking for group of words, and topics themselves as probability distributions on words. It is also important to notice that the order of the words and the grammatical role of the words (subjects, objects, verbs, etc.) are not considered in the model.
#
# Before proceeding with topic modelling, it is advisable to apply the lemmatization technique which aims to reduce the word into a common base word or root word, then facilitating grouping similar words.

# %% [markdown]
# Using the *Spacy* module, the Spacy pipeline is applied to **doc**, which contains the cleaned text.

# %%
nlp = spacy.load('en_core_web_sm') # inizializza creando la spacy pipeline
# nlp è del pacchetto spacy e fa da: tokenizer, parser, ner,...

lemm_doc = nlp(doc) # modello che ti fa la lemmatization
 # riduce a radice/parola base ogni singolo token per facilitare il topic modelling -> lo salva dentro lemm_doc

# %% [markdown]
# The lemmatized version of the document is then generated, and the 24th token along with its lemma is printed, as an example.

# %%
lemm_text = []
for token in lemm_doc:
  lemm_text.append(token.lemma_) # .lemma is one of the operations that spacy pipeline does

print(lemm_doc[23])
print(lemm_text[23])
# Out:
# located
# locate

# %% [markdown]
# Indices are identified in the text where the token *docstart* is present, indicating a potential starting point for distinct documents. The text is then partitioned into five segments, likely representing separate sections. The *NLTK* library is then applied to process words, and the resulting data is organized into a *Pandas* dataframe.

# %%
for i in range(len(lemm_text)):
  if lemm_text[i] == 'docstart':
    print(i) # printa gli indici in cui è presente 'docstart' nella colonna id, in modo da dividere il text in 5 docs
# Out:
# 3596
# 4889
# 7992
# 15931

# %%
lemm_d1 = lemm_text[0:3596]
lemm_d2 = lemm_text[3597:4889]
lemm_d3 = lemm_text[4890:7992]
lemm_d4 = lemm_text[7993:15931]
lemm_d5 = lemm_text[15932:]
lemm_docs = [lemm_d1, lemm_d2, lemm_d3, lemm_d4, lemm_d5]

# %%
# %%capture
import numpy as np
import nltk
import re

nltk.download('stopwords') # set of stopwords yet present in NLTK

# %%
lemm_data = [' '.join(word for word in sent) for sent in lemm_docs]
# # list comprehension: risultato è una lista in cui ogni elemento è una stringa che rappresenta la lista
# di parole originale convertita in una singola stringa con le parole separate da spazi.
lemm_data_df = pd.DataFrame(lemm_data, columns = ['Documents'])

lemm_data_df
# Out:
#                                            Documents
# 0  loan security agreement date january silicon v...
# 1  date march thinkplus investment limited lender...
# 2  loan agreement loan agreement date september e...
# 3  loan security agreement loan security agreemen...
# 4  loan agreement loan agreement agreement make e...

# %% [markdown]
# *CountVectorizer* from *scikit-learn* module is used to convert textual data into a structured Document-Term Matrix (DTM). This matrix represents the frequency of terms in the given documents: parameters like *max_df* and *min_df* are employed to filter out terms based on their occurrence frequency in the documents, and English stopwords are excluded.
# The resulting DTM is then organized into a *Pandas* dataframe.

# %%
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer(max_df = 0.8, min_df = 0.1, stop_words = 'english') # cv è il vectorizer

# max_df=0.8 significa che le parole sopra al 80% di freq non vengono contate nella DTM

# NB: tfidf (term-frequency-inverse-document-frquency) do the same but in different way: it diminishes
# the weights of terms more frequent (as stopwords) and increases the weights of terms that occur rarely

# %%
lemm_dtm = cv.fit_transform(lemm_data_df['Documents'])  # addestramento sulla base dei dati di input per imparare il vocabolario
# + trasformazione in numeri nella matrice
# viene creata la DTM contenente il conteggio delle parole lemmatizzate
lemm_dtm_df = pd.DataFrame(lemm_dtm.toarray(), columns = cv.get_feature_names_out())
# DTM trasformata in un dataframe di pandas

# %% [markdown]
# After several attempts in finding the right number of topics, the LDA model is executed with 3 topics and a specified random state for reproducibility; then it is fitted to the Document-Term Matrix, and retrieves the topic-term distributions.

# %%
from sklearn.decomposition import LatentDirichletAllocation as lda

LDA = lda(n_components = 3, random_state = 22)
# modello di ML che trova i 3 topics nascosti all'interno dei 5 documenti
LDA.fit(lemm_dtm) # viene fittato il modello sulla nostra DTM
# Out:
# LatentDirichletAllocation(n_components=3, random_state=22)

# %%
for index,topic in enumerate(LDA.components_):
    print(f'THE TOP 15 WORDS FOR TOPIC #{index}')
    print([cv.get_feature_names_out()[i] for i in topic.argsort()[-15:]])
    print('\n')

# per ognuno dei 3 topic vengono printate le 15 parole piu frequenti in ogni topic, da cui suggeriamo gli argomenti
# Out:
# THE TOP 15 WORDS FOR TOPIC #0
# ['financial', 'certificate', 'deposit', 'property', 'lien', 'extension', 'permit', 'section', 'subsidiary', 'credit', 'event', 'collateral', 'agent', 'lender', 'borrower']
#
#
# THE TOP 15 WORDS FOR TOPIC #1
# ['accrue', 'refer', 'china', 'airland', 'usd', 'shanghai', 'sign', 'share', 'funding', 'tranche', 'fax', 'address', 'mean', 'article', 'borrower']
#
#
# THE TOP 15 WORDS FOR TOPIC #2
# ['terminal', 'project', 'lease', 'fee', 'coal', 'page', 'trustee', 'expense', 'indenture', 'advance', 'bond', 'section', 'equipment', 'issuer', 'bank']

# %% [markdown]
# Exploring the topics derived from the data using LDA model and analyzing the 15 most frequent words within each topic, 3 distinctive themes can be discerned. The first topic delves into financial agreements and lending, as suggested by terms like *certificate*, *lender*, and *borrower*. The second one focuses on international business and funding, indicating a global financial perspective and possible agreements between USA and China, since there are terms like *usd*, *shangai*, *share* and *tranche*. In the end, the last topic centers around financial and legal contracts, encompassing words like *trustee*, *lease* and *bond*, suggesting contractual aspects in large-scale projects.
# \
# Through this analysis it is gained a nuanced understanding of the diverse subjects encapsulated within the different topics.

# %% [markdown]
# The *transform* method, using the pre-trained LDA model, gives another matrix containing the topics' probability distributions for each document. Each row corresponds to a document and each column corresponds to a topic. A new `Topic` column is added to the dataframe, where each entry denotes the dominant topic for the respective document, determined by finding the index with the highest probability in the transformed matrix.
#
# \
# Consequently, *pyLDAvis* extracts insights from a fitted LDA topic model, providing a user-friendly and interactive web-based visualization. By clarifying topics extracted from textual data, *pyLDAvis* enables a dynamic and intuitive exploration of the underlying structures uncovered during the topic modeling process.

# %%
lemm_topic_results = LDA.transform(lemm_dtm)
lemm_data_df['Topic'] = lemm_topic_results.argmax(axis = 1)
lemm_data_df
# Out:
#                                            Documents  Topic
# 0  loan security agreement date january silicon v...      0
# 1  date march thinkplus investment limited lender...      1
# 2  loan agreement loan agreement date september e...      2
# 3  loan security agreement loan security agreemen...      0
# 4  loan agreement loan agreement agreement make e...      0

# %%
from IPython.display import HTML

HTML(filename='/content/drive/MyDrive/lda_visualization.html')
# Out:
# <link rel="stylesheet" type="text/css" href="https://cdn.jsdelivr.net/gh/bmabey/pyLDAvis@3.4.0/pyLDAvis/js/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el5351391376161657123918920031" style="background-color:white;"></div>
# <script type="text/javascript">
#
# var ldavis_el5351391376161657123918920031_data = {"mdsDat": {"x": [0.04224026959086279, -0.15985695649321416, 0.11761668690235146], "y": [-0.13558027125081493, 0.036830723739902246, 0.09874954751091274], "topics": [1, 2, 3], "cluster": [1, 1, 1], "Freq": [68.92092729094027, 25.0064528792112, 6.072619829848533]}, "tinfo": {"Term": ["borrower", "bank", "issuer", "equipment", "bond", "lender", "section", "article", "mean", "indenture", "address", "advance", "share", "trustee", "funding", "china", "equity", "expense", "sign", "coal", "register", "accrue", "page", "fax", "agent", "dispute", "terminal", "project", "cash", "exchange", "lender", "certificate", "effective", "subsidiary", "indebtedness", "perfection", "license", "capital", "thousand", "course", "thereof", "designate", "warranty", "jurisdiction", "exceed", "commitment", "hereof", "board", "extension", "month", "present", "borrower", "hereunder", "option", "policy", "collateral", "contest", "dollar", "amortization", "expect", "agent", "exclusive", "period", "ordinary", "lien", "permit", "maintain", "form", "financial", "credit", "event", "reasonably", "benefit", "deposit", "property", "equity", "statement", "principal", "claim", "section", "occur", "code", "advance", "payable", "rate", "issuer", "indenture", "coal", "terminal", "pier", "finance", "shiploader", "supplemental", "ton", "reclaimer", "project", "car", "conveyor", "pittston", "design", "bond", "facility", "trustee", "redemption", "silo", "stacker", "throughput", "unload", "virginia", "basic", "associates", "commissioner", "dominion", "exclusion", "hopper", "bank", "equipment", "page", "assignment", "building", "section", "lease", "advance", "expense", "fifth", "commonwealth", "fee", "locate", "liability", "tax", "act", "loss", "directly", "control", "remedy", "article", "income", "proceed", "payable", "change", "event", "rate", "tranche", "airland", "shanghai", "usd", "bizexpress", "jilun", "rongbin", "shi", "worksoft", "zhang", "british", "rmb", "subscription", "solution", "standing", "virgin", "belong", "cayman", "incorporate", "island", "precede", "recipient", "region", "registered", "thinkplus", "town", "abbott", "airmail", "appropriately", "chen", "article", "misleading", "fax", "hong", "mean", "kong", "address", "second", "refer", "borrower", "sign", "road", "funding", "warranties", "share", "resolution", "accrue", "china", "exchange", "cash", "dispute", "equity", "register"], "Freq": [532.0, 130.0, 74.0, 93.0, 66.0, 244.0, 122.0, 27.0, 24.0, 31.0, 18.0, 69.0, 24.0, 27.0, 25.0, 21.0, 29.0, 48.0, 16.0, 19.0, 18.0, 20.0, 25.0, 10.0, 226.0, 14.0, 17.0, 18.0, 12.0, 11.0, 243.85398015791083, 34.29098210563048, 26.709714300105222, 60.56741306713592, 23.90065992564921, 22.02247918028628, 21.075300503685416, 21.071690284430023, 20.13733967870235, 20.127152132047506, 19.19339998988626, 19.18675346890213, 25.55949550483784, 17.292727040548403, 17.292723781122376, 16.347451802535193, 15.417648689526743, 15.413637707593344, 53.712557650192366, 19.014358042378017, 14.411374677437514, 512.8848921482804, 11.629545023743866, 24.85474191230441, 21.526568568436765, 79.16786952374905, 11.60564748432385, 23.91339755910886, 10.697959827185171, 10.697958266924799, 215.46237379173093, 29.537141505140543, 31.023246878117252, 20.12734383232493, 51.456180632028726, 55.42252158804506, 27.127613193639696, 25.468284206096573, 34.163119358025995, 63.16553796514215, 67.9806638917005, 22.85724489515804, 28.68904785159745, 35.48373646545154, 38.90027083367491, 26.739214378668855, 32.345641831874914, 32.34548870857083, 28.807764691784314, 56.44039307552302, 25.04379071484797, 27.773730771450932, 32.44212271869144, 27.30090173341759, 26.506723418618616, 73.95085342069223, 30.701616096490536, 19.48885085870668, 17.086115449304376, 13.0815564312105, 9.04475310801578, 7.475173792411551, 7.475173792411551, 7.475173792411551, 6.6742619835327694, 17.086646308585742, 5.8733501727672515, 5.8733501727672515, 5.8733501727672515, 5.869754153545472, 6 ...

# %% [markdown]
# Using the *prepare* method of *pyLDAvis.lda_model* library, the interactive graph above is obtained.
#
# This visualization includes: a scatter plot where each point represents a topic, the distance between points indicates the similarity between topics the size of the points represents the prevalence of topics in the corpus; a bar chart on the side displaying the 30 most relevant terms for the selected topic, in which the light-blue part corresponds to the overall frequency of each term, while the red part is the estimated term frequency within the selected topic, indicating the relative prevalence of a specific term within the chosen topic.
#
# It is possible to choose both the preferred topic and the values of lambda from the respective dropdown lists.
# The lambda parameter in this context is related to the interactivity of the visualization: it controls the relevance of terms displayed in the visualization.
# \
# Values of lambda very close to 0 will show terms that are more specific for a chosen topic, so terms that are "important" for that specific topic but not necessarily "important" for the whole corpus will be seen.
# \
# Values of lambda close to 1 will show those terms that have the highest ratio between frequency of the terms for that specific topic and the overall frequency of the terms from the corpus.
# \
# So, changing the value of lambda will influence how terms are ranked and displayed in the visualization. It allows to explore topics with different emphases on term relevance.

# %% [markdown]
# ## Sentiment Analysis

# %% [markdown]
# Sentiment Analysis seeks to discern and extract opinions embedded within a given text. Its goal is to measure the attitude, sentiments, evaluations and emotions expressed by a speaker or writer through computational analysis of subjectivity in the text.
# \
# **VADER** (Valence Aware Dictionary for sEntiment Reasoning) is a model, accessible in the *NLTK* package, used for sentiment analysis and it considers both the polarity (positive/negative) and intensity (strength) of emotions;
# VADER sentiment analysis operates based on a dictionary that correlates lexical features to emotion intensities, known as sentiment scores. To derive the sentiment score of a given text, one can obtain it by summing up the intensity associated with each word in the text.

# %%
# %%capture
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# %%
sid = SentimentIntensityAnalyzer() # modello di ML che misura la polarità delle parole nei diversi topic

# %%
df_sent = lemm_data_df[['Documents']] # creo un nuovo dataset selezionando solo la colonna documents lemmatizzati
df_sent['scores'] = df_sent['Documents'].apply(lambda Documents: sid.polarity_scores(Documents))
# viene creata una colonna, applicando una funzione lambda, la quale utilizza sid per assegnare un punteggio di polarità al documento
df_sent['compound']  = df_sent['scores'].apply(lambda score_dict: score_dict['compound'])
# fa lo stesso però considerando solo il compound score
df_sent['comp_score'] = df_sent['compound'].apply(lambda c: 'positive' if c >=0 else 'negative')
# ancora lo stesso scegliendo positive o negative
df_sent
# Out:
#                                            Documents  \
# 0  loan security agreement date january silicon v...
# 1  date march thinkplus investment limited lender...
# 2  loan agreement loan agreement date september e...
# 3  loan security agreement loan security agreemen...
# 4  loan agreement loan agreement agreement make e...
#
#                                               scores  compound comp_score
# 0  {'neg': 0.068, 'neu': 0.718, 'pos': 0.215, 'co...    1.0000   positive
# 1  {'neg': 0.033, 'neu': 0.69, 'pos': 0.277, 'com...    0.9999   positive
# 2  {'neg': 0.065, 'neu': 0.756, 'pos': 0.178, 'co...    0.9999   positive
# 3  {'neg': 0.043, 'neu': 0.735, 'pos': 0.222, 'co...    1.0000   positive
# 4  {'neg': 0.042, 'neu': 0.628, 'pos': 0.331, 'co...    1.0000   positive

# %% [markdown]
# A new table **df_sent** has been created, containing for each of the five documents, the scores of the sentiment analysis, especially highlighting the compound score (computed by normalizing the other scores: negative, neutral and positive): all the compound scores of the five documents are basically one, suggesting uniformly strong positive sentiment. These results suggest that the analyzed document were drafted for regulation, not for sanctioning potential financial misconduct.

# %% [markdown]
# ## Interactive Dashboard

# %% [markdown]
# *Dash*, a python framework created by *plotly*, can be used to present data in a visual way, using an interactive dashboard.
# \
# Two different interactive dashboards will be presented.

# %%
# %%capture
# !pip install dash

# %%
import dash
import plotly.express as px
from dash import dcc, html
from dash.dependencies import Input, Output

# %%
norm_df.loc[0:3596, 'Document']=1
norm_df.loc[3597:4889, 'Document']=2
norm_df.loc[4890:7992, 'Document']=3
norm_df.loc[7993:15931, 'Document']=4
norm_df.loc[15932:, 'Document']=5
norm_df['Document'] = norm_df['Document'].astype(int)

# %%
df_no_O = norm_df.loc[norm_df['ner_tags'] != 'O']

# %%
color_mapping = {
    'I-PER': 'blue',
    'I-LOC': 'green',
    'I-ORG': 'orange',
    'I-MISC': 'purple'
}

app = dash.Dash(__name__)
app.layout = html.Div([
    dcc.Dropdown(
        id='document-dropdown', # set the unique identifier for the dropdown component  (gli identifiers vengono poi richiamati nel callback)
        # create the list of options that will appear in the dropdown -> options tells what is inside the dropdown
        options=[{'label': str(doc), 'value': doc} for doc in df_no_O['Document'].unique()], # list comprehension with dictionary
        value=df_no_O['Document'].min(), # initial value of dropdown -> 1 in this case
        style={'width': '50%'} # set the width of dropdown to 50% of its container
    ),
    # component used for create interactive graph
    dcc.Graph(id='ner-tags-bar-chart'), # unique identifier for the graph component is ner-tags-bar-chart
])

@app.callback( # .. decorator is used to specify the relationships between inputs and outputs of dash application
    Output('ner-tags-bar-chart', 'figure'), # output is the figure property of the dash component with identifier ner-tags-bar-chart
    [Input('document-dropdown', 'value')] # input is the value property of the dash component with identifier document-dropdown
)
def update_figure(selected_document): # takes a selected document as input and updates a bar chart using the Plotly
                                      # library to visualize the frequency distribution of NER tags in the specified document
    filtered_df = df_no_O[df_no_O['Document'] == selected_document] # filters the DataFrame to include only the rows where the value in the 'Document' column matches the specified selected_document

    ner_tags_counts = filtered_df['ner_tags'].value_counts() # per ogni documento selezionato conto i valori di ner_tags
    # queste frequenze le inserisco in un bar graph dove sulla X c'è l'index (I-PER,...) e sulla Y i valori delle frquenze
    fig = px.bar(ner_tags_counts,
                 x=ner_tags_counts.index,
                 y=ner_tags_counts.values,
                 color=ner_tags_counts.index,
                 color_discrete_map=color_mapping,
                 labels={'x':'NER Tags', 'y':'Frequency'})
    fig.update_xaxes(title_text='NER Tags')
    fig.update_layout(legend_title_text='NER Tags')
    return fig

# %%
# common pattern used in Python scripts that involve running a web application using the Dash framework
if __name__ == '__main__': # when the script is the main program being executed, its value is set to '__main__'
  app.run_server(debug=True,port=8050) # if the script is the main program, run the Dash web application specified in the app variable
# 8050 is the port number on which the server will listen for incoming requests

# %% [markdown]
# The first interactive dashboard presents the absolute frequency of NER tags for each document, utilizing the normalized dataset (*df_no_O*), from which the **O** labels have been excluded due to their notably higher prevalence compared to the other four NER tags.
# \
# This dashboard reveals a well-balanced scenario: **I-ORG** dominates in documents 1 and 3, **I-LOC** in the second document, while **I-PER** is prominent in the last two documents. As for **I-MISC**, all seven observations are concentrated in the fifth document.

# %%
lemm_data_df['Count'] = lemm_data_df['Documents'].apply(lambda x: len(x.split()))
lemm_data_df['doc'] = range(1, len(lemm_data_df) + 1)
lemm_data_df['doc'] = lemm_data_df['doc'].astype(str)

# %%
app2 = dash.Dash(__name__)

color_mapping2 = {
    '1': 'blue',
    '2': 'green',
    '3': 'orange',
    '4': 'purple',
    '5': 'red'
}

app2.layout = html.Div([
    dcc.Dropdown(
        id='document-dropdown',
        options=[{'label': str(doc), 'value': doc} for doc in lemm_data_df['Topic'].unique()],
        value=lemm_data_df['Topic'].min(),
        style={'width': '50%'}
    ),
    dcc.Graph(id='word-freq-bar-chart'),
])

@app2.callback(
    Output('word-freq-bar-chart', 'figure'),
    [Input('document-dropdown', 'value')]
)
def update_figure2(selected_topic):

    filtered_data = lemm_data_df[lemm_data_df['Topic'] == selected_topic]


    fig2 = px.bar(filtered_data,
                 x='doc',
                 y='Count',
                 color='doc',
                 color_discrete_map=color_mapping2,
                 labels={'x':'doc', 'y':'Words Count'})

    fig2.update_xaxes(title_text='Documents')
    fig2.update_yaxes(title_text='Words Count')
    fig2.update_layout(legend_title_text='Documents')

    return fig2

# %%
if __name__ == '__main__':
  app2.run_server(debug=True,port=8051)

# %% [markdown]
# The second interactive dashboard illustrates the word count distribution for each document across the three topics.
# \
# In particular, topic 1 comprises words exclusively from the second document, while topic 2 solely encompasses words from the third document. Conversely, topic 0 is distributed across the remaining three documents, with the fourth document being notably longer compared to the others.

# %% [markdown]
# # Neural Network

# %% [markdown]
# The operations of data preparation and cleaning performed above, are repeated on the test dataset *FIN3.csv*.

# %%
df_test = pd.read_csv('/content/drive/MyDrive/FIN3.csv', sep = ';')
df_test.columns = ['id', 'chunk_label', 'empty', 'ner_tags']
df_test = df_test.drop(0)
df_test = df_test.dropna()
df_test.index = range(1, 11673)
df_test.drop("empty", axis = 'columns', inplace = True)
df_test['id'] = df_test['id'].map(str.lower)

removed = []

for index, id, chunk_label, ner_tags in df_test.itertuples():
  if id.isalnum() == False or id.isalpha() == False or id in stopwords or len(id) < 2:
    removed.append(index)

norm_df_test = df_test.drop(removed)
norm_df_test.index = range(1, 4906)

# %% [markdown]
# ## Token Ordinal Encoding (1 feature)

# %%
# %%capture
# !pip install seqeval

# %%
import urllib
import sklearn
import logging
import os
import numpy as np
from seqeval.metrics import classification_report
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from sklearn.model_selection import train_test_split

# %% [markdown]
# The training and validation datasets are created from **norm_df** using the *train_test_split* function.
# Specifically, the function splits the **norm_df** dataframe into feature (`id`) and target variable (`ner_tags`) for both the training (*raw_train*, *ner_train*) and validation (*raw_valid, ner_valid*) sets. The proportion of data allocated to the validation set is 20% (set by the *test_size* parameter).
#
# The test is split in the same way into *raw_test* and *ner_test*.
#
# Finally labels used in the Named Entity Recognition task are saved into a set.

# %%
raw_train, raw_valid, ner_train, ner_valid = train_test_split(norm_df['id'], norm_df['ner_tags'],
                                                              test_size = 0.2, random_state = 22)
raw_test = norm_df_test['id']
ner_test = norm_df_test['ner_tags']

ner_labels = set()
ner_labels.add('I-MISC')
ner_labels.add('I-PER')
ner_labels.add('I-LOC')
ner_labels.add('I-ORG')
ner_labels.add('O')

# %%
ner_labels
# Out:
# {'I-LOC', 'I-MISC', 'I-ORG', 'I-PER', 'O'}

# %% [markdown]
# Firstly *raw_train*, *raw_valid* and *raw_test* are converted into lists. These lists are processed using the *Tokenizer*, which maps the tokens to sequences of numerical indices. The mapping of each tag to a unique numerical index is saved in *tag2idx* dictionary and the reverse mapping is saved in *idx2tag* dictionary.
# \
# The NER tags in the training, validation and test sets are afterwards converted into numerical sequences using the previous mappings. This step is needed for representing categorical labels in a format suitable for training machine learning models.

# %%
raw_train = raw_train.tolist()
raw_valid = raw_valid.tolist()
raw_test = raw_test.tolist()

# %%
# preparazione dei dati per un modello di NLP, convertendo i testi in sequenze numeriche e creando mapping tra etichette e indici.

tok = Tokenizer() # Crea un oggetto Tokenizer
tok.fit_on_texts(raw_train + raw_valid + raw_test)
# imposta il vocabolario del tokenizzatore, assegnando un indice univoco a ciascun termine nel corpus.

# ogni parola nel testo viene sostituita con il suo indice corrispondente nel vocabolario per tutti e 3 i dati
train_sequences = tok.texts_to_sequences(raw_train)
valid_sequences = tok.texts_to_sequences(raw_valid)
test_sequences = tok.texts_to_sequences(raw_test)


tag2idx = {tag: idx for idx, tag in enumerate(ner_labels)}
# Crea un dizionario che mappa ciascuna etichetta NER a un indice numerico; gli indici sono assegnati in base all'ordine di apparizione delle etichette
idx2tag = {idx: tag for tag, idx in tag2idx.items()}
# Crea un dizionario inverso, mappando gli indici alle etichette corrispondenti.

ner_train_sequences = [tag2idx[tag] for tag in ner_train]
#  Converte i ner_tags del set di addestramento (ner_train) in sequenze numeriche utilizzando il mapping definito in tag2idx
ner_valid_sequences = [tag2idx[tag] for tag in ner_valid] # uguale ma per ner_valid
ner_test_sequences = [tag2idx[tag] for tag in ner_test] # # uguale ma per ner_test

# %% [markdown]
# The NER tag sequences are one-hot encoded using the *to_categorical* function from *Keras*, representing each tag as a binary vector.
#
# The input features *train_sequences*, *valid_sequences* and *test_sequences* are then converted to *NumPy* arrays.
#
# Finally, the target variables *y_train*, *y_valid*, *y_test* are also converted to *NumPy* arrays, ensuring that also target labels are in a format suitable for training and evaluation in a machine learning model.

# %%
y_train = to_categorical(ner_train_sequences, num_classes = len(ner_labels), dtype = 'int32')
y_valid = to_categorical(ner_valid_sequences, num_classes = len(ner_labels), dtype = 'int32')
y_test = to_categorical(ner_test_sequences, num_classes = len(ner_labels), dtype = 'int32')

# %%
X_train = np.array(train_sequences)
X_valid = np.array(valid_sequences)
X_test = np.array(test_sequences)
y_train = np.array(y_train)
y_valid = np.array(y_valid)
y_test = np.array(y_test)

# %% [markdown]
# ## Model (1 feature)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from keras.preprocessing.text import Tokenizer
from keras.utils import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Bidirectional
from keras.callbacks import EarlyStopping
from keras.initializers import Constant
from sklearn.model_selection import train_test_split
import re
import os

# %% [markdown]
# A *GloVe* pre-trained word embeddings is now loaded from the *glove.6B.100d.txt.word2vec* file in the *embedding_index* dictionary, where each word is associated with its corresponding vector representation.
#
# *GloVe* embeddings are often pre-trained on large corpora, capturing general language patterns, therefore the model benefits from knowledge gained on a broader dataset, enhancing its ability to generalize even with a limited training data.

# %%
# creo una lista contenente i tokens del dizionario Glove e ne misuro la lunghezza
embeddings_index = {}
f = open(os.path.join('/content/drive/MyDrive/', 'glove.6B.100d.txt.word2vec'))
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400001 word vectors.

# %%
word_index = tok.word_index
print('Found %s unique tokens.' % len(word_index))
# Out:
# Found 2845 unique tokens.

# %% [markdown]
# The embedding matrix is now prepared for the neural network model.
# For each word in the *Tokenizer*, the corresponding vector in the pre-trained *GloVe* embeddings is added to to the embedding matrix, if the word is found; otherwise, a random vector is assigned. The resulting matrix serves as the initial embedding layer for the neural network.

# %%
max_features = 10000
num_words = min(max_features, len(word_index)) + 1
print(num_words)

embedding_dim = 100

# first create a matrix of zeros, this is our embedding matrix
embedding_matrix = np.zeros((num_words, embedding_dim))

# for each word in our tokenizer lets try to find that word in our w2v model
for word, i in word_index.items():
    if i > max_features:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # we found the word - add that words vector to the matrix
        embedding_matrix[i] = embedding_vector
    else:
        # doesn't exist, assign a random vector
        embedding_matrix[i] = np.random.randn(embedding_dim)
# Out:
# 2846

# %% [markdown]
# The neural network model is defined as follows.
#
# It incorporates an Embedding layer initialized with pre-trained *GloVe* embeddings, followed by bidirectional and unidirectional *LSTM* layers. The model includes a Dense layer with *ReLU* activation and a final Dense layer with *Softmax* activation for multi-class classification, giving the probability of the token being in a specific class. The model is compiled using *Categorical crossentropy* loss and the *Adam* optimizer.

# %%
# Set the number of LSTM output units
lstm_out = 200

# Create a Sequential model
model = Sequential()

# Add an Embedding layer with pre-trained GloVe embeddings
model.add(Embedding(num_words, embedding_dim,
                    embeddings_initializer = Constant(embedding_matrix),
                    input_length=X_train.shape[1]))

# Add a bidirectional LSTM layer
model.add(Bidirectional(LSTM(lstm_out, return_sequences = True)))

# Add a unidirectional LSTM layer
model.add(LSTM(lstm_out))

# Add a Dense layer with ReLU activation
model.add(Dense(lstm_out, activation = 'relu'))

# Add the output Dense layer with softmax activation
model.add(Dense(5, activation = 'softmax'))

# Compile the model
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 1, 100)            284600
#
#  bidirectional (Bidirection  (None, 1, 400)            481600
#  al)
#
#  lstm_1 (LSTM)               (None, 200)               480800
#
#  dense (Dense)               (None, 200)               40200
#
#  dense_1 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 1288205 (4.91 MB)
# Trainable params: 1288205 (4.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %% [markdown]
# Visual representation of the neural network:

# %%
from keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# The model training is stopped when the validation loss remains equal for 4 successive epochs
early_stopping = EarlyStopping(monitor = 'val_loss', patience = 4, restore_best_weights = True)

# %% [markdown]
# The neural network model is trained on the training data for 50 epochs with a batch size of 64. Validation data is used for model evaluation during training and early stopping is applied to prevent overfitting.

# %%
batch_size = 64
history = model.fit(X_train, y_train, epochs=50, batch_size = batch_size, verbose = 1,
                    validation_data = (X_valid, y_valid), callbacks = [early_stopping])
# Out:
# Epoch 1/50
# 224/224 [==============================] - 30s 45ms/step - loss: 0.1806 - accuracy: 0.9606 - val_loss: 0.0786 - val_accuracy: 0.9768
# Epoch 2/50
# 224/224 [==============================] - 6s 25ms/step - loss: 0.0593 - accuracy: 0.9828 - val_loss: 0.0598 - val_accuracy: 0.9818
# Epoch 3/50
# 224/224 [==============================] - 5s 21ms/step - loss: 0.0433 - accuracy: 0.9869 - val_loss: 0.0569 - val_accuracy: 0.9832
# Epoch 4/50
# 224/224 [==============================] - 3s 13ms/step - loss: 0.0362 - accuracy: 0.9885 - val_loss: 0.0609 - val_accuracy: 0.9813
# Epoch 5/50
# 224/224 [==============================] - 3s 14ms/step - loss: 0.0315 - accuracy: 0.9897 - val_loss: 0.0585 - val_accuracy: 0.9846
# Epoch 6/50
# 224/224 [==============================] - 5s 21ms/step - loss: 0.0295 - accuracy: 0.9894 - val_loss: 0.0666 - val_accuracy: 0.9816
# Epoch 7/50
# 224/224 [==============================] - 4s 16ms/step - loss: 0.0281 - accuracy: 0.9902 - val_loss: 0.0696 - val_accuracy: 0.9810

# %% [markdown]
# NER tags are now predicted on the *X_test* using the previously trained model.
# Predictions and their corresponding true values are displayed.

# %%
y_pred = model.predict(X_test)
y_pred = np.argmax(y_pred, axis=-1)
y_true = np.argmax(y_test, axis=-1)

for idx in range(len(X_test)):
    word_idx = int(X_test[idx])
    true_tag = idx2tag[y_true[idx]]
    pred_tag = idx2tag[y_pred[idx]]

    print(f'{tok.index_word[word_idx]:15}  {true_tag:6} | {pred_tag}')
# Out:
# 154/154 [==============================] - 3s 6ms/step
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              I-ORG  | O
# december         O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# logo             O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# llp              O      | I-ORG
# page             O      | O
# december         O      | O
# table            O      | O
# contents         O      | O
# clause           O      | O
# headings         O      | O
# page             O      | O
# interpretation   O      | O
# loan             O      | O
# interest         O      | O
# redemption       O      | O
# early            O      | O
# redemptions      O      | O
# representations  O      | O
# undertakings     O      | O
# subordination    O      | O
# costs            O      | O
# partial          O      | O
# payments         O      | O
# assignment       O      | O
# whole            O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# severance        O      | O
# notices          O      | O
# confidentiality  O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# disputes         O      | O
# page             O      | O
# december         O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# made             O      | O
# december         O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# private          O      | O
# company          O      | O
# limited          O      | O
# liability        O      | O
# incorporated     O      | O
# laws             O      | O
# france           I-LOC  | I-LOC
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# usine            I-LOC  | I-ORG
# de               I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | I-LOC
# represented      O      | O
# mr               O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | O
# hereinafter      O      | O
# referred         O      | O
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              I-ORG  | O
# company          O      | O
# incorporated     O      | O
# delaware         O      | O
# registered       O      | O
# number           O      | O
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-LOC
# massachusetts    I-LOC  | I-LOC
# represented      O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | O
# hereinafter      O      | O
# referred         O      | O
# hereinafter      O      | O
# referred         O      | O
# severally        O      | O
# jointly          O      | O
# whereas          O      | O
# borrower         I-PER  | I-PER
# intends          O      | O
# develop          O      | O
# plant            O      | O
# france           I-LOC  | I-LOC
# production       O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# entered          O      | O
# agreement        O      | O
# sale             O      | O
# purchase         O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# date             O      | O
# hereof           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# agreed           O      | O
# consideration    O      | O
# borrower         I-PER  | I-PER
# entering         O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# lender           I-PER  | I-PER
# lender           I-PER  | I-PER
# make             O      | O
# available        O      | O
# borrower         I-PER  | I-PER
# way              O      | O
# subordinated     O      | O
# loan             O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# parties          O      | O
# wish             O      | O
# set              O      | O
# terms            O      | O
# conditions       O      | O
# loan             O      | O
# agreement        O      | O
# now              O      | O
# parties          O      | O
# agree            O      | O
# follows          O      | O
# interpretation   O      | O
# loan             O      | O
# agreement        O      | O
# unless           O      | O
# specified        O      | O
# context          O      | O
# requires         O      | O
# words            O      | O
# importing        O      | O
# singular         O      | O
# include          O      | O
# plural           O      | O
# vice             O      | O
# versa            O      | O
# words            O      | O
# importing        O      | O
# gender           O      | O
# include          O      | O
# genders          O      | O
# words            O      | O
# importing        O      | O
# whole            O      | O
# treated          O      | O
# including        O      | O
# reference        O      | O
# part             O      | O
# whole            O      | O
# reference        O      | O
# article          O      | O
# relevant         O      | O
# article          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# modified         O      | O
# amended          O      | O
# varied           O      | O
# supplemented     O      | O
# replaced         O      | O
# time             O      | O
# time             O      | O
# reference        O      | O
# provision        O      | O
# law              O      | O
# reference        O      | O
# provision        O      | O
# extended         O      | O
# applied          O      | O
# amended          O      | O
# consolidated     O      | O
# re               O      | O
# enacted          O      | O
# application      O      | O
# thereof          O      | O
# modified         O      | O
# time             O      | O
# time             O      | O
# construed        O      | O
# including        O      | O
# reference        O      | O
# order            O      | O
# instrument       O      | O
# regulation       O      | O
# subordinate      O      | O
# legislation      O      | O
# time             O      | O
# time             O      | O
# made             O      | O
# except           O      | O
# provided         O      | O
# loan             O      | O
# agreement        O      | O
# page             O      | O
# december         O      | O
# references       O      | O
# words            O      | O
# ôøω              O      | O
# include          O      | O
# ôøω              O      | O
# ôøω              O      | O
# including        O      | O
# ôøω              O      | O
# construed        O      | O
# without          O      | O
# limitation       O      | O
# reference        O      | O
# writing          O      | O
# written          O      | O
# includes         O      | O
# faxes            O      | O
# mail             O      | O
# headings         O      | O
# used             O      | O
# loan             O      | O
# agreement        O      | O
# affect           O      | O
# construction     O      | O
# interpretation   O      | O
# words            O      | O
# phrases          O      | O
# defined          O      | O
# part             O      | O
# loan             O      | O
# agreement        O      | O
# bear             O      | O
# meanings         O      | O
# throughout       O      | O
# agreement        O      | O
# wherever         O      | O
# loan             O      | O
# agreement        O      | O
# provision        O      | O
# made             O      | O
# giving           O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# person           O      | O
# unless           O      | O
# stated           O      | O
# unreasonably     O      | O
# withheld         O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# writing          O      | O
# word             O      | O
# ôøω              O      | O
# notify           O      | O
# ôøω              O      | O
# construed        O      | O
# accordingly      O      | O
# notices          O      | O
# served           O      | O
# parties          O      | O
# designated       O      | O
# representative   O      | O
# registered       O      | O
# address          O      | O
# party            O      | O
# address          O      | O
# party            O      | O
# may              O      | O
# notify           O      | O
# party            O      | O
# time             O      | O
# time             O      | O
# loan             O      | O
# lender           I-PER  | I-PER
# grants           O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# total            O      | O
# principal        O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# disbursed        O      | O
# borrower         I-PER  | I-PER
# two              O      | O
# instalments      O      | O
# follows          O      | O
# first            O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# november         O      | O
# second           O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# january          O      | O
# actual           O      | O
# disbursement     O      | O
# date             O      | O
# last             O      | O
# instalment       O      | O
# loan             O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# paid             O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# account          O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# follows          O      | O
# bank             I-ORG  | I-ORG
# ing              O      | I-ORG
# belgium          I-LOC  | I-LOC
# succursale       O      | O
# en               O      | I-LOC
# france           I-LOC  | I-LOC
# branch           O      | O
# immeuble         I-LOC  | I-PER
# les              I-LOC  | I-LOC
# caryatides       I-LOC  | O
# boulevard        I-LOC  | I-LOC
# carnot           I-LOC  | O
# lille            I-LOC  | I-ORG
# cedex            I-LOC  | O
# account          O      | O
# number           O      | O
# iban             O      | I-ORG
# number           O      | O
# bic              O      | O
# number           O      | O
# ingbfrpp         O      | I-ORG
# code             O      | O
# guichet          O      | I-ORG
# du               O      | O
# compte           O      | O
# cle              O      | I-ORG
# rib              O      | O
# bank             I-ORG  | I-ORG
# account          O      | O
# may              O      | O
# nominated        O      | O
# time             O      | O
# time             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# pursuant         O      | O
# article          O      | O
# loan             O      | O
# used             O      | O
# borrower         I-PER  | I-PER
# solely           O      | O
# finance          O      | O
# works            O      | O
# arising          O      | O
# relating         O      | O
# construction     O      | O
# borrower         I-PER  | I-PER
# plant            O      | O
# avoidance        O      | O
# doubt            O      | O
# loan             O      | O
# used             O      | O
# increase         O      | O
# management       O      | O
# remuneration     O      | O
# repayment        O      | O
# indebtedness     O      | O
# borrowed         O      | O
# money            O      | O
# capital          O      | O
# distribution     O      | O
# borrower         I-PER  | I-PER
# equity           O      | O
# holders          O      | O
# interest         O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# effective        O      | O
# date             O      | O
# pay              O      | O
# interest         O      | O
# arrears          O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# outstanding      O      | O
# time             O      | O
# time             O      | O
# interest         O      | O
# calculated       O      | O
# rate             O      | O
# three            O      | O
# percent          O      | O
# per              O      | O
# calendar         O      | O
# year             O      | O
# compounded       O      | O
# annually         O      | O
# actual           O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# plus             O      | O
# accrued          O      | O
# interest         O      | O
# amounts          O      | O
# due              O      | O
# hereunder        O      | O
# provided         O      | O
# upon             O      | O
# failure          O      | O
# repay            O      | O
# part             O      | O
# loan             O      | O
# due              O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# set              O      | O
# forth            O      | O
# page             O      | O
# december         O      | O
# clause           O      | O
# loan             O      | O
# agreement        O      | O
# foregoing        O      | O
# rate             O      | O
# increase         O      | O
# amount           O      | O
# equal            O      | O
# twelve           O      | O
# month            O      | O
# euribor          O      | I-ORG
# rate             O      | O
# determined       O      | O
# business         O      | O
# day              O      | O
# preceding        O      | O
# default          O      | O
# reported         O      | O
# wall             I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# journal          O      | I-ORG
# plus             O      | O
# three            O      | O
# unpaid           O      | O
# amount           O      | O
# means            O      | O
# period           O      | O
# days             O      | O
# case             O      | O
# may              O      | O
# beginning        O      | O
# january          O      | O
# ending           O      | O
# december         O      | O
# interest         O      | O
# calculated       O      | O
# basis            O      | O
# actual           O      | O
# number           O      | O
# days             O      | O
# elapsed          O      | O
# borrower         I-PER  | I-PER
# repay            O      | O
# loan             O      | O
# interest         O      | O
# accrued          O      | O
# hereunder        O      | O
# date             O      | O
# falling          O      | O
# five             O      | O
# years            O      | O
# effective        O      | O
# date             O      | O
# save             O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# prepay           O      | O
# part             O      | O
# loan             O      | O
# accordance       O      | O
# article          O      | O
# provided         O      | O
# event            O      | O
# lender           I-PER  | I-PER
# terminates       O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# pursuant         O      | O
# article          O      | O
# thereof          O      | O
# repayment        O      | O
# date             O      | O
# effective        O      | O
# date             O      | O
# termination      O      | O
# interest         O      | O
# due              O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# first            O      | O
# second           O      | O
# instalments      O      | O
# payable          O      | O
# whole            O      | O
# repayment        O      | O
# date             O      | O
# purposes         O      | O
# articles         O      | O
# et               O      | O
# seq              O      | I-ORG
# french           I-MISC | O
# code             O      | O
# de               O      | O
# la               O      | O
# consommation     O      | I-ORG
# lender           I-PER  | I-PER
# hereby           O      | O
# informs          O      | O
# borrower         I-PER  | I-PER
# rate             O      | O
# taux             O      | O
# effectif         O      | I-PER
# global           O      | I-ORG
# loan             O      | O
# three            O      | O
# percent          O      | O
# payments         O      | O
# made             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# euros            O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# electronic       O      | O
# transfer         O      | O
# account          O      | O
# held             O      | O
# silicon          I-LOC  | I-ORG
# valley           I-LOC  | I-ORG
# bank             I-ORG  | I-ORG
# account          O      | O
# number           O      | O
# swift            O      | O
# code             O      | O
# credit           O      | O
# early            O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# times            O      | O
# allowed          O      | O
# prepay           O      | O
# loan             O      | O
# whole            O      | O
# part             O      | O
# without          O      | O
# premium          O      | O
# penalty          O      | O
# provided         O      | O
# whole            O      | O
# multiples        O      | O
# eur              O      | O
# ten              O      | O
# days             O      | O
# prior            O      | O
# written          O      | O
# notice           O      | O
# delivered        O      | O
# lender           I-PER  | I-PER
# notwithstanding  O      | O
# provisions       O      | O
# clause           O      | O
# early            O      | O
# redemption       O      | O
# agreement        O      | O
# include          O      | O
# accrued          O      | O
# interest         O      | O
# amount           O      | O
# prepaid          O      | O
# representations  O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# represents       O      | O
# warrants         O      | O
# company          O      | O
# duly             O      | O
# incorporated     O      | O
# validly          O      | O
# existing         O      | O
# laws             O      | O
# jurisdiction     O      | O
# incorporation    O      | O
# obligations      O      | O
# expressed        O      | O
# assumed          O      | O
# valid            O      | O
# binding          O      | O
# obligations      O      | O
# entry            O      | O
# performance      O      | O
# loan             O      | O
# agreement        O      | O
# will             O      | O
# conflict         O      | O
# provision        O      | O
# law              O      | O
# regulation       O      | O
# applicable       O      | O
# constitutional   O      | O
# documents        O      | O
# agreement        O      | O
# binding          O      | O
# upon             O      | O
# assets           O      | O
# power            O      | O
# enter            O      | O
# perform          O      | O
# deliver          O      | O
# loan             O      | O
# agreement        O      | O
# transactions     O      | O
# contemplated     O      | O
# therein          O      | O
# undertakings     O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# undertakes       O      | O
# things           O      | O
# necessary        O      | O
# maintain         O      | O
# corporate        O      | O
# existence        O      | O
# page             O      | O
# december         O      | O
# obtain           O      | O
# maintain         O      | O
# comply           O      | O
# terms            O      | O
# authorisation    O      | O
# required         O      | O
# applicable       O      | O
# law              O      | O
# regulation       O      | O
# enable           O      | O
# carry            O      | O
# activities       O      | O
# ii               O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# comply           O      | O
# applicable       O      | O
# laws             O      | O
# regulations      O      | O
# subordination    O      | O
# event            O      | O
# insolvency       O      | O
# proceedings      O      | O
# initiated        O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# event            O      | O
# moratorium       O      | O
# debts            O      | O
# borrower         I-PER  | I-PER
# proposed         O      | O
# composition      O      | O
# assignment       O      | O
# arrangement      O      | O
# creditors        O      | O
# obligation       O      | O
# repay            O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# subordinated     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# lending          O      | O
# financial        O      | O
# institution      O      | O
# way              O      | O
# related          O      | O
# works            O      | O
# present          O      | O
# future           O      | O
# notwithstanding  O      | O
# whether          O      | O
# indebtedness     O      | O
# recoverable      O      | O
# process          O      | O
# law              O      | O
# conditional      O      | O
# unconditional    O      | O
# financial        O      | O
# loans            O      | O
# manufacturer     O      | O
# loans            O      | O
# shareholder      O      | O
# loans            O      | O
# affiliate        O      | O
# control          O      | O
# creditor         O      | O
# means            O      | O
# bank             I-ORG  | I-ORG
# special          O      | O
# purpose          O      | O
# project          O      | O
# company          O      | O
# trust            O      | O
# company          O      | O
# mortgage         O      | O
# company          O      | O
# insurance        O      | O
# company          O      | O
# pension          O      | O
# fund             O      | O
# real             O      | O
# estate           O      | O
# investment       O      | O
# trust            O      | O
# lending          O      | O
# financial        O      | O
# institutions     O      | O
# including        O      | O
# indirect         O      | O
# lenders          O      | O
# loan             O      | O
# participants     O      | O
# providing        O      | O
# debt             O      | O
# equity           O      | O
# lease            O      | O
# bond             O      | O
# financing        O      | O
# financial        O      | O
# services         O      | O
# credit           O      | O
# support          O      | O
# credit           O      | O
# enhancement      O      | O
# way              O      | O
# related          O      | O
# construction     O      | O
# works            O      | O
# borrower         I-PER  | I-PER
# obtain           O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# unless           O      | O
# borrower         I-PER  | I-PER
# provides         O      | O
# unconditional    O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# form             O      | O
# acceptable       O      | O
# lender           I-PER  | I-PER
# sole             O      | O
# discretion       O      | O
# borrower         I-PER  | I-PER
# obtains          O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# provide          O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# upon             O      | O
# execution        O      | O
# assignment       O      | O
# assumption       O      | O
# agreement        O      | O
# whereby          O      | O
# borrower         I-PER  | I-PER
# assigns          O      | O
# rights           O      | O
# assignee         O      | O
# assignee         O      | O
# assumes          O      | O
# obligations      O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# successive       O      | O
# assignments      O      | O
# borrower         I-PER  | I-PER
# rights           O      | O
# loan             O      | O
# agreement        O      | O
# remain           O      | O
# subject          O      | O
# article          O      | O
# provided         O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# released         O      | O
# guarantee        O      | O
# provided         O      | O
# satisfaction     O      | O
# obligations      O      | O
# article          O      | O
# result           O      | O
# assignment       O      | O
# occurs           O      | O
# initial          O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# unless           O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# obtained         O      | O
# case             O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# item             O      | O
# apply            O      | O
# lender           I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# without          O      | O
# consent          O      | O
# borrower         I-PER  | I-PER
# event            O      | O
# change           O      | O
# control          O      | O
# lender           I-PER  | I-PER
# sale             O      | O
# substantially    O      | O
# assets           O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# relates          O      | O
# page             O      | O
# december         O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# giving           O      | O
# security         O      | O
# one              O      | O
# party            O      | O
# hereunder        O      | O
# way              O      | O
# diminish         O      | O
# party            O      | O
# rights           O      | O
# obligations      O      | O
# giving           O      | O
# parties          O      | O
# successor        O      | O
# rights           O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# including        O      | O
# amendments       O      | O
# hereto           O      | O
# written          O      | O
# request          O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# cooperate        O      | O
# borrower         I-PER  | I-PER
# creditors        O      | O
# entering         O      | O
# timely           O      | O
# manner           O      | O
# direct           O      | O
# agreements       O      | O
# may              O      | O
# reasonably       O      | O
# necessary        O      | O
# customary        O      | O
# project          O      | O
# financing        O      | O
# works            O      | O
# agreements       O      | O
# may              O      | O
# include          O      | O
# provisions       O      | O
# permit           O      | O
# creditors        O      | O
# event            O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# permit           O      | O
# lender           I-PER  | I-PER
# terminate        O      | O
# loan             O      | O
# agreement        O      | O
# take             O      | O
# loan             O      | O
# agreement        O      | O
# ii               O      | O
# step             O      | O
# rectify          O      | O
# cure             O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# iii              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# whole            O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# constitutes      O      | O
# entire           O      | O
# agreement        O      | O
# parties          O      | O
# respect          O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# herein           O      | O
# stated           O      | O
# instruments      O      | O
# documents        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# hereto           O      | O
# contains         O      | O
# representations  O      | O
# undertakings     O      | O
# agreements       O      | O
# parties          O      | O
# loan             O      | O
# agreement        O      | O
# supersedes       O      | O
# prior            O      | O
# meetings         O      | O
# correspondence   O      | O
# negotiations     O      | O
# parties          O      | O
# representations  O      | O
# warranties       O      | O
# covenants        O      | O
# agreements       O      | O
# collateral       O      | O
# understandings   O      | O
# oral             O      | O
# expressed        O      | O
# implied          O      | O
# kind             O      | O
# parties          O      | O
# hereto           O      | O
# respecting       O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# contained        O      | O
# referred         O      | O
# herein           O      | O
# neither          O      | O
# party            O      | O
# relied           O      | O
# statement        O      | O
# outside          O      | O
# written          O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# variation        O      | O
# loan             O      | O
# agreement        O      | O
# must             O      | O
# writing          O      | O
# signed           O      | O
# behalf           O      | O
# parties          O      | O
# waiver           O      | O
# right            O      | O
# loan             O      | O
# agreement        O      | O
# effective        O      | O
# writing          O      | O
# applies          O      | O
# party            O      | O
# waiver           O      | O
# addressed        O      | O
# circumstances    O      | O
# given            O      | O
# severance        O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# appears          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provisions       O      | O
# will             O      | O
# remain           O      | O
# force            O      | O
# parties          O      | O
# obliged          O      | O
# replace          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# provisions       O      | O
# valid            O      | O
# enforceable      O      | O
# legal            O      | O
# binding          O      | O
# way              O      | O
# new              O      | I-LOC
# provisions       O      | O
# differ           O      | O
# little           O      | O
# possible         O      | O
# original         O      | O
# provisions       O      | O
# taking           O      | O
# account          O      | O
# object           O      | O
# purpose          O      | O
# contents         O      | O
# loan             O      | O
# agreement        O      | O
# notices          O      | O
# notice           O      | O
# communication    O      | O
# required         O      | O
# given            O      | O
# loan             O      | O
# agreement        O      | O
# writing          O      | O
# delivered        O      | O
# party            O      | O
# required         O      | O
# receive          O      | O
# notice           O      | O
# communication    O      | O
# address          O      | O
# set              O      | O
# borrower         I-PER  | I-PER
# usine            O      | I-ORG
# de               O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# page             O      | O
# december         O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | I-LOC
# attention        O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | O
# ceo              I-LOC  | O
# lender           I-PER  | I-PER
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-LOC
# massachusetts    I-LOC  | I-LOC
# attention        O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | O
# vice             O      | O
# president        O      | O
# address          O      | O
# relevant         O      | O
# party            O      | O
# may              O      | O
# specify          O      | O
# notice           O      | O
# writing          O      | O
# parties          O      | O
# notice           O      | O
# communication    O      | O
# sent             O      | O
# mail             O      | O
# facsimile        O      | O
# must             O      | O
# confirmed        O      | O
# commercial       O      | O
# courier          O      | O
# notice           O      | O
# communication    O      | O
# deemed           O      | O
# duly             O      | O
# given            O      | O
# delivered        O      | O
# personally       O      | O
# left             O      | O
# address          O      | O
# referred         O      | O
# article          O      | O
# delivered        O      | O
# commercial       O      | O
# courier          O      | O
# date             O      | O
# signature        O      | O
# courier          O      | O
# receipt          O      | O
# sent             O      | O
# fax              O      | O
# time             O      | O
# transmission     O      | O
# sent             O      | O
# mail             O      | O
# time             O      | O
# despatch         O      | O
# deemed           O      | O
# receipt          O      | O
# previous         O      | O
# paragraphs       O      | O
# article          O      | O
# within           O      | O
# business         O      | O
# hours            O      | O
# meaning          O      | O
# pm               O      | O
# monday           O      | O
# friday           O      | O
# day              O      | O
# public           O      | O
# holiday          O      | O
# place            O      | O
# receipt          O      | O
# business         O      | O
# next             O      | O
# starts           O      | O
# place            O      | O
# receipt          O      | O
# confidentiality  O      | O
# party            O      | O
# undertakes       O      | O
# time             O      | O
# loan             O      | O
# agreement        O      | O
# period           O      | O
# five             O      | O
# years            O      | O
# termination      O      | O
# loan             O      | O
# agreement        O      | O
# disclose         O      | O
# person           O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# article          O      | O
# means            O      | O
# knowledge        O      | O
# financial        O      | O
# data             O      | O
# operating        O      | O
# data             O      | O
# trade            O      | O
# secrets          O      | O
# experience       O      | O
# know             O      | O
# information      O      | O
# kinds            O      | O
# whatever         O      | O
# form             O      | O
# technologies     O      | I-ORG
# finances         O      | O
# costs            O      | O
# marketing        O      | O
# business         O      | O
# including        O      | O
# limited          O      | O
# term             O      | O
# sheets           O      | O
# notes            O      | O
# analyses         O      | O
# agreements       O      | O
# compilations     O      | O
# studies          O      | O
# interpretations  O      | O
# suchlike         O      | O
# disclosed        O      | O
# behalf           O      | O
# disclosing       O      | O
# party            O      | O
# whether          O      | O
# marked           O      | O
# confidential     O      | O
# information      O      | O
# including        O      | O
# confidential     O      | O
# information      O      | O
# communicated     O      | O
# receiving        O      | O
# party            O      | O
# orally           O      | O
# reduced          O      | O
# writing          O      | O
# exclude          O      | O
# information      O      | O
# becomes          O      | O
# improper         O      | O
# action           O      | O
# inaction         O      | O
# receiving        O      | O
# party            O      | O
# affiliate        O      | O
# agent            O      | O
# consultant       O      | O
# employee         O      | O
# generally        O      | O
# available        O      | O
# public           O      | O
# ii               O      | O
# possession       O      | O
# known            O      | O
# prior            O      | O
# receipt          O      | O
# disclosing       O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iii              O      | O
# rightfully       O      | O
# disclosed        O      | O
# third            O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iv               O      | O
# independently    O      | O
# developed        O      | O
# without          O      | O
# use              O      | O
# confidential     O      | O
# information      O      | O
# disclosing       O      | O
# party            O      | O
# ôøω              O      | O
# party            O      | O
# may              O      | O
# disclose         O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# page             O      | O
# december         O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# need             O      | O
# know             O      | O
# information      O      | O
# purposes         O      | O
# carrying         O      | O
# party            O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# party            O      | O
# ensure           O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# discloses        O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# comply           O      | O
# article          O      | O
# may              O      | O
# required         O      | O
# law              O      | O
# court            O      | O
# order            O      | O
# governmental     O      | O
# regulatory       O      | O
# authority        O      | O
# party            O      | O
# use              O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# french           I-MISC | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# correspondence   O      | O
# notices          O      | O
# written          O      | O
# communications   O      | O
# english          I-MISC | I-LOC
# disputes         O      | O
# dispute          O      | O
# arises           O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# directors        O      | O
# senior           O      | O
# representatives  O      | O
# parties          O      | O
# authority        O      | O
# settle           O      | O
# dispute          O      | O
# will             O      | O
# within           O      | O
# ten              O      | O
# days             O      | O
# written          O      | O
# request          O      | O
# one              O      | O
# party            O      | O
# meet             O      | O
# good             O      | O
# faith            O      | O
# effort           O      | O
# resolve          O      | O
# dispute          O      | O
# disputes         O      | O
# arising          O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# resolved         O      | O
# pursuant         O      | O
# article          O      | O
# finally          O      | O
# settled          O      | O
# rules            O      | O
# arbitration      O      | O
# international    O      | I-ORG
# chamber          O      | O
# commerce         O      | O
# three            O      | O
# arbitrators      O      | O
# appointed        O      | O
# accordance       O      | O
# said             O      | O
# rules            O      | O
# arbitration      O      | O
# conducted        O      | O
# english          I-MISC | I-LOC
# seat             O      | O
# paris            I-LOC  | I-LOC
# events           O      | O
# default          O      | O
# following        O      | O
# events           O      | O
# considered       O      | O
# events           O      | O
# default          O      | O
# respect          O      | O
# loan             O      | O
# agreement        O      | O
# borrower         I-PER  | I-PER
# default          O      | O
# payment          O      | O
# part             O      | O
# principal        O      | O
# unpaid           O      | O
# accrued          O      | O
# interest         O      | O
# loan             O      | O
# thirty           O      | O
# days             O      | O
# become           O      | O
# due              O      | O
# payable          O      | O
# whether          O      | O
# maturity         O      | O
# date             O      | O
# fixed            O      | O
# prepayment       O      | O
# acceleration     O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# admits           O      | O
# inability        O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# reason           O      | O
# actual           O      | O
# anticipated      O      | O
# financial        O      | O
# difficulties     O      | O
# suspends         O      | O
# making           O      | O
# payments         O      | O
# debts            O      | O
# commences        O      | O
# negotiations     O      | O
# one              O      | O
# creditors        O      | O
# view             O      | O
# rescheduling     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# state            O      | O
# suspension       O      | O
# payments         O      | O
# cessation        O      | O
# des              O      | O
# paiements        O      | I-LOC
# within           O      | O
# meaning          O      | O
# article          O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# corporate        O      | O
# action           O      | O
# legal            O      | O
# proceedings      O      | O
# procedures       O      | O
# steps            O      | O
# taken            O      | O
# reason           O      | O
# borrower         I-PER  | I-PER
# financial        O      | O
# difficulties     O      | O
# relation         O      | O
# suspension       O      | O
# payments         O      | O
# moratorium       O      | O
# indebtedness     O      | O
# winding          O      | O
# dissolution      O      | O
# administration   O      | O
# reorganisation   O      | O
# solvent          O      | O
# winding          O      | O
# dissolution      O      | O
# reorganisation   O      | O
# carried          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# unreasonably     O      | O
# withheld         O      | O
# delayed          O      | O
# borrower         I-PER  | I-PER
# composition      O      | O
# compromise       O      | O
# assignment       O      | O
# arrangement      O      | O
# creditor         O      | O
# borrower         I-PER  | I-PER
# page             O      | O
# december         O      | O
# appointment      O      | O
# liquidator       O      | O
# receiver         O      | O
# administrator    O      | O
# administrative   O      | O
# receiver         O      | O
# compulsory       O      | O
# manager          O      | O
# similar          O      | O
# officer          O      | O
# respect          O      | O
# borrower         I-PER  | I-PER
# assets           O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# commences        O      | O
# proceedings      O      | O
# conciliation     O      | O
# accordance       O      | O
# articles         O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# judgment         O      | O
# sauvegarde       O      | I-ORG
# redressement     O      | I-ORG
# judiciaire       O      | O
# liquidation      O      | O
# judiciaire       O      | O
# entered          O      | O
# relation         O      | O
# borrower         I-PER  | I-PER
# articles         O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# judgment         O      | O
# entered          O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# fail             O      | O
# observe          O      | O
# perform          O      | O
# obligation       O      | O
# observed         O      | O
# performed        O      | O
# loan             O      | O
# agreement        O      | O
# within           O      | O
# thirty           O      | O
# days             O      | O
# written          O      | O
# notice           O      | O
# lender           I-PER  | I-PER
# perform          O      | O
# observe          O      | O
# obligation       O      | O
# borrower         I-PER  | I-PER
# stops            O      | O
# construction     O      | O
# works            O      | O
# acknowledges     O      | O
# will             O      | O
# unable           O      | O
# unwilling        O      | O
# ...
# agent            O      | O
# service          O      | O
# process          O      | O
# entries          O      | O
# register         O      | O
# conclusive       O      | O
# binding          O      | O
# purposes         O      | O
# absent           O      | O
# manifest         O      | O
# error            O      | O
# servicer         O      | O
# holders          O      | O
# may              O      | O
# treat            O      | O
# person           O      | O
# entity           O      | O
# whose            O      | O
# name             O      | O
# recorded         O      | O
# register         O      | O
# holder           O      | O
# hereunder        O      | O
# purposes         O      | O
# agreement        O      | O
# register         O      | O
# available        O      | O
# inspection       O      | O
# copying          O      | O
# holder           O      | O
# normal           O      | O
# business         O      | O
# hours            O      | O
# upon             O      | O
# reasonable       O      | O
# prior            O      | O
# notice           O      | O
# servicer         O      | O
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# hereto           O      | O
# caused           O      | O
# agreement        O      | O
# duly             O      | O
# executed         O      | O
# day              O      | O
# year             O      | O
# first            O      | O
# written          O      | O
# pim              O      | I-ORG
# ashford          I-ORG  | I-LOC
# venture          I-ORG  | I-ORG
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# investments      O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# reit             O      | O
# operating        O      | O
# lp               O      | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# sole             O      | O
# member           O      | O
# prisa            O      | O
# iii              O      | O
# op               O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# lp               O      | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# manager          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# pim              O      | I-ORG
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# sole             O      | O
# member           O      | O
# prudential       O      | I-ORG
# investment       O      | O
# management       O      | O
# inc              O      | O
# delaware         O      | O
# corporation      O      | O
# sole             O      | O
# member           O      | O
# name             O      | O
# james            I-PER  | I-LOC
# walker           O      | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# finance          I-ORG  | O
# lp               I-ORG  | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# finance          I-ORG  | O
# general          I-ORG  | O
# partner          I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# name             O      | O
# david            I-PER  | I-LOC
# brooks           I-PER  | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# servicing        I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# name             O      | O
# david            I-PER  | I-LOC
# brooks           I-PER  | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# schedule         O      | O
# loan             O      | O
# documents        O      | O
# source           O      | O
# onecle           O      | I-LOC
# business         O      | O
# contracts        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# crocs            O      | O
# inc              O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# logo             O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# dated            O      | O
# november         O      | O
# entered          O      | O
# among            O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# twenty           O      | O
# five             O      | O
# million          O      | O
# dollars          O      | O
# words            O      | O
# add              O      | O
# minimum          O      | O
# net              O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# covenant         O      | O
# section          O      | O
# loan             O      | O
# agreement        O      | O
# hereby           O      | O
# added            O      | O
# read             O      | O
# full             O      | O
# follows          O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# conditions       O      | O
# precedent        O      | O
# effectiveness    O      | O
# amendment        O      | O
# subject          O      | O
# prior            O      | O
# satisfaction     O      | O
# following        O      | O
# conditions       O      | O
# amendment        O      | O
# bank             I-ORG  | I-ORG
# received         O      | O
# original         O      | O
# amendment        O      | O
# duly             O      | O
# executed         O      | O
# borrower         I-PER  | I-PER
# bank             I-ORG  | I-ORG
# documents        O      | O
# borrower         I-PER  | I-PER
# executed         O      | O
# delivered        O      | O
# bank             I-ORG  | I-ORG
# revolving        O      | O
# note             O      | O
# documents        O      | O
# instruments      O      | O
# bank             I-ORG  | I-ORG
# may              O      | O
# reasonably       O      | O
# require          O      | O
# miscellaneous    O      | O
# survival         O      | O
# representations  O      | O
# warranties       O      | O
# representations  O      | O
# warranties       O      | O
# made             O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# documents        O      | O
# relating         O      | O
# thereto          O      | O
# including        O      | O
# without          O      | O
# limitation       O      | O
# loan             O      | O
# documents        O      | O
# furnished        O      | O
# connection       O      | O
# amendment        O      | O
# survive          O      | O
# execution        O      | O
# delivery         O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# investigation    O      | O
# bank             I-ORG  | I-ORG
# closing          O      | O
# affect           O      | O
# representations  O      | O
# warranties       O      | O
# right            O      | O
# bank             I-ORG  | I-ORG
# rely             O      | O
# thereon          O      | O
# events           O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# aware            O      | O
# events           O      | O
# now              O      | O
# constitute       O      | O
# passage          O      | O
# time             O      | O
# giving           O      | O
# notice           O      | O
# constitute       O      | O
# event            O      | O
# default          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# agreements       O      | O
# documents        O      | O
# instruments      O      | O
# now              O      | O
# hereafter        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# terms            O      | O
# hereof           O      | O
# pursuant         O      | O
# terms            O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# hereby           O      | O
# amended          O      | O
# reference        O      | O
# therein          O      | O
# loan             O      | O
# agreement        O      | O
# mean             O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# loan             O      | O
# agreement        O      | O
# remains          O      | O
# effect           O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# remain           O      | O
# full             O      | O
# force            O      | O
# effect           O      | O
# borrower         I-PER  | I-PER
# ratifies         O      | O
# confirms         O      | O
# agreements       O      | O
# covenants        O      | O
# contained        O      | O
# therein          O      | O
# borrower         I-PER  | I-PER
# hereby           O      | O
# confirms         O      | O
# giving           O      | O
# effect           O      | O
# amendment        O      | O
# event            O      | O
# default          O      | O
# default          O      | O
# exists           O      | O
# date             O      | O
# severability     O      | O
# provision        O      | O
# amendment        O      | O
# held             O      | O
# court            O      | O
# competent        O      | O
# jurisdiction     O      | O
# invalid          O      | O
# unenforceable    O      | O
# impair           O      | O
# invalidate       O      | O
# remainder        O      | O
# amendment        O      | O
# effect           O      | O
# thereof          O      | O
# confined         O      | O
# provision        O      | O
# held             O      | O
# invalid          O      | O
# unenforceable    O      | O
# applicable       O      | O
# law              O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# executed         O      | O
# pursuant         O      | O
# hereto           O      | O
# deemed           O      | O
# made             O      | O
# performable      O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# laws             O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# successors       O      | O
# assigns          O      | O
# amendment        O      | O
# binding          O      | O
# upon             O      | O
# inure            O      | O
# benefit          O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# respective       O      | O
# successors       O      | O
# assigns          O      | O
# provided         O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# rights           O      | O
# obligations      O      | O
# hereunder        O      | O
# without          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# bank             I-ORG  | I-ORG
# counterparts     O      | O
# amendment        O      | O
# may              O      | O
# executed         O      | O
# one              O      | O
# counterparts     O      | O
# executed         O      | O
# deemed           O      | O
# original         O      | O
# taken            O      | O
# together         O      | O
# constitute       O      | O
# one              O      | O
# instrument       O      | O
# headings         O      | O
# headings         O      | O
# captions         O      | O
# arrangements     O      | O
# used             O      | O
# amendment        O      | O
# convenience      O      | O
# affect           O      | O
# interpretation   O      | O
# amendment        O      | O
# oral             O      | O
# agreements       O      | O
# amendment        O      | O
# together         O      | O
# loan             O      | O
# documents        O      | O
# written          O      | O
# represents       O      | O
# final            O      | O
# agreement        O      | O
# lenders          O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# contradicted     O      | O
# evidence         O      | O
# prior            O      | O
# contemporaneous  O      | O
# subsequent       O      | O
# oral             O      | O
# agreements       O      | O
# parties          O      | O
# unwritten        O      | O
# oral             O      | O
# agreements       O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# entered          O      | O
# amendment        O      | O
# respective       O      | O
# duly             O      | O
# authorized       O      | O
# officers         O      | O
# date             O      | O
# first            O      | O
# written          O      | O
# crocs            O      | O
# inc              O      | O
# peter            I-PER  | I-PER
# case             I-PER  | O
# peter            I-PER  | I-PER
# case             I-PER  | O
# title            O      | O
# chief            O      | O
# financial        O      | O
# officer          O      | O
# address          O      | O
# monarch          I-LOC  | O
# park             I-LOC  | I-LOC
# place            I-LOC  | O
# niwot            I-LOC  | I-ORG
# colorado         I-LOC  | I-LOC
# attention        O      | O
# keith            I-PER  | O
# love             I-PER  | O
# treasury         O      | O
# manager          O      | O
# telecopier       O      | I-ORG
# telephone        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# douglas          I-PER  | I-LOC
# lambell          O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# title            O      | O
# vice             O      | O
# president        O      | O
# address          O      | O
# street           I-LOC  | I-LOC
# floor            I-LOC  | I-LOC
# san              I-LOC  | I-LOC
# diego            I-LOC  | O
# california       I-LOC  | I-LOC
# attention        O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# vp               O      | O
# telecopier       O      | I-ORG
# telephone        O      | O
# source           O      | O
# onecle           O      | I-LOC
# business         O      | O
# contracts        O      | O

# %%
def plot_history(history):
    acc = history.history['accuracy']
    val_acc = history.history['val_accuracy']
    loss = history.history['loss']
    val_loss = history.history['val_loss']
    x = range(1, len(acc) + 1)

    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(x, acc, 'b', label='Training Acc')
    plt.plot(x, val_acc, 'r', label='Validation Acc')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.subplot(1, 2, 2)
    plt.plot(x, loss, 'b', label='Training Loss')
    plt.plot(x, val_loss, 'r', label='Validation Loss')
    plt.title('Training and Validation Loss')
    plt.legend()

# %%
plot_history(history)

# %% [markdown]
# The previous graph represents the behaviour of the Accuracy and the Loss of both the training and validation set at every epoch.
# \
# The training accuracy reaches approximately 0.99 and the training loss drops to less than 0.03. The validation accuracy reaches approximately 0.985, affirming the model's effective generalization to unseen data.
# \
# Furthermore the validation loss remains low at around 0.07, indicating robust generalization capabilities without overfitting.
# \
# Overall, these results suggest that the model has demonstrated good performance in both the training and validation phases.

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
print(classification_report(y_true, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4548
#            1       0.50      0.70      0.59        61
#            2       0.98      0.89      0.93       192
#            3       0.00      0.00      0.00         7
#            4       0.37      0.33      0.35        97
#
#     accuracy                           0.96      4905
#    macro avg       0.57      0.58      0.57      4905
# weighted avg       0.96      0.96      0.96      4905
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# The classification report reveals an overall model accuracy of 96%, which surpasses the ratio between **O** tags and the entire set of NER tags. This is particularly noteworthy as **O** tags constitute 92% of all observations, a significantly high proportion. It indicates that the model performs better than one that simply predicts **O** tags. In essence, the model successfully distinguishes between entities of interest and others, outperforming a model reliant on **O** predictions that would be primarily influenced by the prevalence of that class.
# \
# In the minority classes (**I-LOC** and **I-ORG**) the precision is low, suggesting a greater difficulty in correctly identifying instances in this category.
# The recall, representing the model's ability to correctly identify all positive instances, shows varying results across classes, indicating potential areas for improvement. Overall, the weighted average of F1-scores is equal to 96% and reflects a good balance of precision and recall across all considered classes.
#
# Considering that the dataset is unbalanced, with the **O** class having significantly bigger instances, giving priority to the F1 score becomes crucial. Indeed, the F1 score, being the armonic mean of precision and recall, provides a more comprehensive evaluation.

# %%
cf_matrix = confusion_matrix(y_true, y_pred)

# %%
def plot_confusion_matrix(y_preds, y_test, labels):
    cm = confusion_matrix(y_true, y_preds, normalize="true")
    fig, ax = plt.subplots(figsize=(6, 6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
    disp.plot(cmap="BuPu", values_format=".2f", ax=ax, colorbar=False)
    plt.title("Normalized confusion matrix")
    ax.grid(False)
    plt.show()

# %%
plot_confusion_matrix(y_pred, y_true, ner_labels)

# %% [markdown]
# The normalized confusion matrix provides valuable insights into the model's performance across different NER tags. Each row of the matrix corresponds to the true class, while each column represents the predicted class. The color intensity in each cell reflects the recall, which is the proportion of true positive predictions relative to the total true instances for that class.
# \
# Strong diagonal elements can be observed, especially for the **O** and the **I-PER** NER tags, indicating high correctness in predictions for these categories. However, off-diagonal elements reveal areas where the model encounters challenges.

# %% [markdown]
# ## Token Ordinal Encoding (2 features)

# %% [markdown]
# It is now introduced a new model that extends beyond the use of only word identifiers `id` and incorporates an additional feature `chunk_labels`.
# The addition of this new variable aims to enrich the informational context available to the model, with the goal of achieving more accurate predictions.
# \
# The dataset preparation for the validation, training and test phases mirrors the procedures undertaken previously.
# The dataset is again divided into features and target variable, encompassing both `id` and `chunk_label` features. The categorical encoding of `chunk_label` is computed as before. Subsequently, the resulting sequences and chunk labels are organized to construct input arrays for each dataset split (*training*, *validation*, and *test*).

# %%
# %%capture

raw_train_2, raw_valid_2, ner_train_2, ner_valid_2 = train_test_split(norm_df[['id','chunk_label']], norm_df['ner_tags'],
                                                              test_size = 0.2, random_state = 22)
raw_test_2 = norm_df_test[['id','chunk_label']]
ner_test_2 = norm_df_test['ner_tags']

raw_train_2['chunk_label'] = raw_train_2['chunk_label'].astype('category').cat.codes
raw_valid_2['chunk_label'] = raw_valid_2['chunk_label'].astype('category').cat.codes
raw_test_2['chunk_label'] = raw_test_2['chunk_label'].astype('category').cat.codes

chunk_train = raw_train_2['chunk_label']
chunk_valid = raw_valid_2['chunk_label']
chunk_test = raw_test_2['chunk_label']

train_sequences_2 = [numero for sublist in train_sequences for numero in sublist]
valid_sequences_2 = [numero for sublist in valid_sequences for numero in sublist]
test_sequences_2 = [numero for sublist in test_sequences for numero in sublist]

chunk_train = chunk_train.to_list()
chunk_valid = chunk_valid.to_list()
chunk_test = chunk_test.to_list()

X_train_2 = np.array([train_sequences_2, chunk_train])
X_valid_2 = np.array([valid_sequences_2, chunk_valid])
X_test_2 = np.array([test_sequences_2, chunk_test])

X_train_2 = X_train_2.T
X_valid_2 = X_valid_2.T
X_test_2 = X_test_2.T

# %% [markdown]
# ## Model (2 features)

# %% [markdown]
# Similarly to the previous model, the neural network structure remains consistent (embedding layer, LSTM layers and the final dense layers). The key difference lies in the input structure, where `chunk_label` is included alongside `id` as part of the feature set. The training and evaluation processes are coherent with the previous model assessment. The introduction of `chunk_label` aims to give additional contextual information to improve the performance of NER tags recognition.

# %%
lstm_out = 200

model = Sequential()
model.add(Embedding(num_words, embedding_dim,
                    embeddings_initializer = Constant(embedding_matrix),
                    input_length=X_train_2.shape[1]))
model.add(Bidirectional(LSTM(lstm_out, return_sequences = True)))
model.add(LSTM(lstm_out))
model.add(Dense(lstm_out, activation = 'relu'))
model.add(Dense(5, activation = 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 2, 100)            284600
#
#  bidirectional_1 (Bidirecti  (None, 2, 400)            481600
#  onal)
#
#  lstm_3 (LSTM)               (None, 200)               480800
#
#  dense_2 (Dense)             (None, 200)               40200
#
#  dense_3 (Dense)             (None, 5)                 1005
#
# =================================================================
# Total params: 1288205 (4.91 MB)
# Trainable params: 1288205 (4.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
batch_size = 64
history_2 = model.fit(X_train_2, y_train, epochs=50, batch_size = batch_size, verbose = 1,
                    validation_data = (X_valid_2, y_valid), callbacks = [early_stopping])
# Out:
# Epoch 1/50
# 224/224 [==============================] - 12s 24ms/step - loss: 0.1552 - accuracy: 0.9635 - val_loss: 0.0667 - val_accuracy: 0.9796
# Epoch 2/50
# 224/224 [==============================] - 3s 11ms/step - loss: 0.0523 - accuracy: 0.9846 - val_loss: 0.0436 - val_accuracy: 0.9869
# Epoch 3/50
# 224/224 [==============================] - 3s 13ms/step - loss: 0.0372 - accuracy: 0.9888 - val_loss: 0.0479 - val_accuracy: 0.9869
# Epoch 4/50
# 224/224 [==============================] - 3s 15ms/step - loss: 0.0292 - accuracy: 0.9912 - val_loss: 0.0486 - val_accuracy: 0.9860
# Epoch 5/50
# 224/224 [==============================] - 3s 11ms/step - loss: 0.0265 - accuracy: 0.9920 - val_loss: 0.0495 - val_accuracy: 0.9872
# Epoch 6/50
# 224/224 [==============================] - 2s 9ms/step - loss: 0.0226 - accuracy: 0.9927 - val_loss: 0.0471 - val_accuracy: 0.9880

# %%
y_pred_2 = model.predict(X_test_2)
y_pred_2 = np.argmax(y_pred_2, axis=-1)
y_true_2 = np.argmax(y_test, axis=-1)

for idx in range(len(X_test)):
    word_idx = int(X_test[idx])
    true_tag_2 = idx2tag[y_true_2[idx]]
    pred_tag_2 = idx2tag[y_pred_2[idx]]

    print(f'{tok.index_word[word_idx]:15}  {true_tag_2:6} | {pred_tag_2}')
# Out:
# 154/154 [==============================] - 2s 3ms/step
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | O
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | I-ORG
# solar            I-ORG  | O
# inc              I-ORG  | O
# december         O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# logo             O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | O
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | I-ORG
# solar            I-ORG  | O
# inc              O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# llp              O      | I-ORG
# page             O      | O
# december         O      | O
# table            O      | O
# contents         O      | O
# clause           O      | O
# headings         O      | O
# page             O      | O
# interpretation   O      | O
# loan             O      | O
# interest         O      | O
# redemption       O      | O
# early            O      | O
# redemptions      O      | O
# representations  O      | O
# undertakings     O      | O
# subordination    O      | O
# costs            O      | O
# partial          O      | O
# payments         O      | O
# assignment       O      | O
# whole            O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# severance        O      | O
# notices          O      | O
# confidentiality  O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# disputes         O      | O
# page             O      | O
# december         O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# made             O      | O
# december         O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | O
# private          O      | O
# company          O      | O
# limited          O      | O
# liability        O      | O
# incorporated     O      | O
# laws             O      | O
# france           I-LOC  | O
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# usine            I-LOC  | I-ORG
# de               I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | O
# represented      O      | O
# mr               O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | O
# hereinafter      O      | O
# referred         O      | O
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              I-ORG  | O
# company          O      | O
# incorporated     O      | O
# delaware         O      | I-LOC
# registered       O      | O
# number           O      | O
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-LOC
# massachusetts    I-LOC  | I-LOC
# represented      O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | O
# hereinafter      O      | O
# referred         O      | O
# hereinafter      O      | O
# referred         O      | O
# severally        O      | O
# jointly          O      | O
# whereas          O      | O
# borrower         I-PER  | I-PER
# intends          O      | O
# develop          O      | O
# plant            O      | O
# france           I-LOC  | O
# production       O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# entered          O      | O
# agreement        O      | O
# sale             O      | O
# purchase         O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# date             O      | O
# hereof           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# agreed           O      | O
# consideration    O      | O
# borrower         I-PER  | I-PER
# entering         O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# lender           I-PER  | I-PER
# lender           I-PER  | I-PER
# make             O      | O
# available        O      | O
# borrower         I-PER  | I-PER
# way              O      | O
# subordinated     O      | O
# loan             O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# parties          O      | O
# wish             O      | O
# set              O      | O
# terms            O      | O
# conditions       O      | O
# loan             O      | O
# agreement        O      | O
# now              O      | O
# parties          O      | O
# agree            O      | O
# follows          O      | O
# interpretation   O      | O
# loan             O      | O
# agreement        O      | O
# unless           O      | O
# specified        O      | O
# context          O      | O
# requires         O      | O
# words            O      | O
# importing        O      | O
# singular         O      | O
# include          O      | O
# plural           O      | O
# vice             O      | O
# versa            O      | O
# words            O      | O
# importing        O      | O
# gender           O      | O
# include          O      | O
# genders          O      | O
# words            O      | O
# importing        O      | O
# whole            O      | O
# treated          O      | O
# including        O      | O
# reference        O      | O
# part             O      | O
# whole            O      | O
# reference        O      | O
# article          O      | O
# relevant         O      | O
# article          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# modified         O      | O
# amended          O      | O
# varied           O      | O
# supplemented     O      | O
# replaced         O      | O
# time             O      | O
# time             O      | O
# reference        O      | O
# provision        O      | O
# law              O      | O
# reference        O      | O
# provision        O      | O
# extended         O      | O
# applied          O      | O
# amended          O      | O
# consolidated     O      | O
# re               O      | O
# enacted          O      | O
# application      O      | O
# thereof          O      | O
# modified         O      | O
# time             O      | O
# time             O      | O
# construed        O      | O
# including        O      | O
# reference        O      | O
# order            O      | O
# instrument       O      | O
# regulation       O      | O
# subordinate      O      | O
# legislation      O      | O
# time             O      | O
# time             O      | O
# made             O      | O
# except           O      | O
# provided         O      | O
# loan             O      | O
# agreement        O      | O
# page             O      | O
# december         O      | O
# references       O      | O
# words            O      | O
# ôøω              O      | O
# include          O      | O
# ôøω              O      | O
# ôøω              O      | O
# including        O      | O
# ôøω              O      | O
# construed        O      | O
# without          O      | O
# limitation       O      | O
# reference        O      | O
# writing          O      | O
# written          O      | O
# includes         O      | O
# faxes            O      | O
# mail             O      | O
# headings         O      | O
# used             O      | O
# loan             O      | O
# agreement        O      | O
# affect           O      | O
# construction     O      | O
# interpretation   O      | O
# words            O      | O
# phrases          O      | O
# defined          O      | O
# part             O      | O
# loan             O      | O
# agreement        O      | O
# bear             O      | O
# meanings         O      | O
# throughout       O      | O
# agreement        O      | O
# wherever         O      | O
# loan             O      | O
# agreement        O      | O
# provision        O      | O
# made             O      | O
# giving           O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# person           O      | O
# unless           O      | O
# stated           O      | O
# unreasonably     O      | O
# withheld         O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# writing          O      | O
# word             O      | O
# ôøω              O      | O
# notify           O      | O
# ôøω              O      | O
# construed        O      | O
# accordingly      O      | O
# notices          O      | O
# served           O      | O
# parties          O      | O
# designated       O      | O
# representative   O      | O
# registered       O      | O
# address          O      | O
# party            O      | O
# address          O      | O
# party            O      | O
# may              O      | O
# notify           O      | O
# party            O      | O
# time             O      | O
# time             O      | O
# loan             O      | O
# lender           I-PER  | I-PER
# grants           O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# total            O      | O
# principal        O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# disbursed        O      | O
# borrower         I-PER  | I-PER
# two              O      | O
# instalments      O      | O
# follows          O      | O
# first            O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# november         O      | O
# second           O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# january          O      | O
# actual           O      | O
# disbursement     O      | O
# date             O      | O
# last             O      | O
# instalment       O      | O
# loan             O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# paid             O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# account          O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# follows          O      | O
# bank             I-ORG  | I-ORG
# ing              O      | I-ORG
# belgium          I-LOC  | I-LOC
# succursale       O      | O
# en               O      | O
# france           I-LOC  | O
# branch           O      | I-ORG
# immeuble         I-LOC  | I-PER
# les              I-LOC  | O
# caryatides       I-LOC  | O
# boulevard        I-LOC  | O
# carnot           I-LOC  | I-PER
# lille            I-LOC  | I-ORG
# cedex            I-LOC  | O
# account          O      | O
# number           O      | O
# iban             O      | I-LOC
# number           O      | O
# bic              O      | O
# number           O      | O
# ingbfrpp         O      | I-ORG
# code             O      | O
# guichet          O      | I-ORG
# du               O      | O
# compte           O      | O
# cle              O      | O
# rib              O      | O
# bank             I-ORG  | I-ORG
# account          O      | O
# may              O      | O
# nominated        O      | O
# time             O      | O
# time             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# pursuant         O      | O
# article          O      | O
# loan             O      | O
# used             O      | O
# borrower         I-PER  | I-PER
# solely           O      | O
# finance          O      | O
# works            O      | O
# arising          O      | O
# relating         O      | O
# construction     O      | O
# borrower         I-PER  | I-PER
# plant            O      | O
# avoidance        O      | O
# doubt            O      | O
# loan             O      | O
# used             O      | O
# increase         O      | O
# management       O      | O
# remuneration     O      | O
# repayment        O      | O
# indebtedness     O      | O
# borrowed         O      | O
# money            O      | O
# capital          O      | O
# distribution     O      | O
# borrower         I-PER  | I-PER
# equity           O      | O
# holders          O      | O
# interest         O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# effective        O      | O
# date             O      | O
# pay              O      | O
# interest         O      | O
# arrears          O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# outstanding      O      | O
# time             O      | O
# time             O      | O
# interest         O      | O
# calculated       O      | O
# rate             O      | O
# three            O      | O
# percent          O      | O
# per              O      | O
# calendar         O      | O
# year             O      | O
# compounded       O      | O
# annually         O      | O
# actual           O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# plus             O      | O
# accrued          O      | O
# interest         O      | O
# amounts          O      | O
# due              O      | O
# hereunder        O      | O
# provided         O      | O
# upon             O      | O
# failure          O      | O
# repay            O      | O
# part             O      | O
# loan             O      | O
# due              O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# set              O      | O
# forth            O      | O
# page             O      | O
# december         O      | O
# clause           O      | O
# loan             O      | O
# agreement        O      | O
# foregoing        O      | O
# rate             O      | O
# increase         O      | O
# amount           O      | O
# equal            O      | O
# twelve           O      | O
# month            O      | O
# euribor          O      | I-ORG
# rate             O      | O
# determined       O      | O
# business         O      | O
# day              O      | O
# preceding        O      | O
# default          O      | O
# reported         O      | O
# wall             I-LOC  | I-ORG
# street           I-LOC  | I-LOC
# journal          O      | I-ORG
# plus             O      | O
# three            O      | O
# unpaid           O      | O
# amount           O      | O
# means            O      | O
# period           O      | O
# days             O      | O
# case             O      | O
# may              O      | O
# beginning        O      | O
# january          O      | O
# ending           O      | O
# december         O      | O
# interest         O      | O
# calculated       O      | O
# basis            O      | O
# actual           O      | O
# number           O      | O
# days             O      | O
# elapsed          O      | O
# borrower         I-PER  | I-PER
# repay            O      | O
# loan             O      | O
# interest         O      | O
# accrued          O      | O
# hereunder        O      | O
# date             O      | O
# falling          O      | O
# five             O      | O
# years            O      | O
# effective        O      | O
# date             O      | O
# save             O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# prepay           O      | O
# part             O      | O
# loan             O      | O
# accordance       O      | O
# article          O      | O
# provided         O      | O
# event            O      | O
# lender           I-PER  | I-PER
# terminates       O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# pursuant         O      | O
# article          O      | O
# thereof          O      | O
# repayment        O      | O
# date             O      | O
# effective        O      | O
# date             O      | O
# termination      O      | O
# interest         O      | O
# due              O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# first            O      | O
# second           O      | O
# instalments      O      | O
# payable          O      | O
# whole            O      | O
# repayment        O      | O
# date             O      | O
# purposes         O      | O
# articles         O      | O
# et               O      | O
# seq              O      | O
# french           I-MISC | O
# code             O      | O
# de               O      | O
# la               O      | O
# consommation     O      | I-ORG
# lender           I-PER  | I-PER
# hereby           O      | O
# informs          O      | O
# borrower         I-PER  | I-PER
# rate             O      | O
# taux             O      | O
# effectif         O      | I-PER
# global           O      | O
# loan             O      | O
# three            O      | O
# percent          O      | O
# payments         O      | O
# made             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# euros            O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# electronic       O      | O
# transfer         O      | O
# account          O      | O
# held             O      | O
# silicon          I-LOC  | I-ORG
# valley           I-LOC  | I-ORG
# bank             I-ORG  | I-ORG
# account          O      | O
# number           O      | O
# swift            O      | O
# code             O      | O
# credit           O      | O
# early            O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# times            O      | O
# allowed          O      | O
# prepay           O      | O
# loan             O      | O
# whole            O      | O
# part             O      | O
# without          O      | O
# premium          O      | O
# penalty          O      | O
# provided         O      | O
# whole            O      | O
# multiples        O      | O
# eur              O      | O
# ten              O      | O
# days             O      | O
# prior            O      | O
# written          O      | O
# notice           O      | O
# delivered        O      | O
# lender           I-PER  | I-PER
# notwithstanding  O      | O
# provisions       O      | O
# clause           O      | O
# early            O      | O
# redemption       O      | O
# agreement        O      | O
# include          O      | O
# accrued          O      | O
# interest         O      | O
# amount           O      | O
# prepaid          O      | O
# representations  O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# represents       O      | O
# warrants         O      | O
# company          O      | O
# duly             O      | O
# incorporated     O      | O
# validly          O      | O
# existing         O      | O
# laws             O      | O
# jurisdiction     O      | O
# incorporation    O      | O
# obligations      O      | O
# expressed        O      | O
# assumed          O      | O
# valid            O      | O
# binding          O      | O
# obligations      O      | O
# entry            O      | O
# performance      O      | O
# loan             O      | O
# agreement        O      | O
# will             O      | O
# conflict         O      | O
# provision        O      | O
# law              O      | O
# regulation       O      | O
# applicable       O      | O
# constitutional   O      | O
# documents        O      | O
# agreement        O      | O
# binding          O      | O
# upon             O      | O
# assets           O      | O
# power            O      | O
# enter            O      | O
# perform          O      | O
# deliver          O      | O
# loan             O      | O
# agreement        O      | O
# transactions     O      | O
# contemplated     O      | O
# therein          O      | O
# undertakings     O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# undertakes       O      | O
# things           O      | O
# necessary        O      | O
# maintain         O      | O
# corporate        O      | O
# existence        O      | O
# page             O      | O
# december         O      | O
# obtain           O      | O
# maintain         O      | O
# comply           O      | O
# terms            O      | O
# authorisation    O      | O
# required         O      | O
# applicable       O      | O
# law              O      | O
# regulation       O      | O
# enable           O      | O
# carry            O      | O
# activities       O      | O
# ii               O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# comply           O      | O
# applicable       O      | O
# laws             O      | O
# regulations      O      | O
# subordination    O      | O
# event            O      | O
# insolvency       O      | O
# proceedings      O      | O
# initiated        O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# event            O      | O
# moratorium       O      | O
# debts            O      | O
# borrower         I-PER  | I-PER
# proposed         O      | O
# composition      O      | O
# assignment       O      | O
# arrangement      O      | O
# creditors        O      | O
# obligation       O      | O
# repay            O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# subordinated     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# lending          O      | O
# financial        O      | O
# institution      O      | O
# way              O      | O
# related          O      | O
# works            O      | O
# present          O      | O
# future           O      | O
# notwithstanding  O      | O
# whether          O      | O
# indebtedness     O      | O
# recoverable      O      | O
# process          O      | O
# law              O      | O
# conditional      O      | O
# unconditional    O      | O
# financial        O      | I-ORG
# loans            O      | O
# manufacturer     O      | O
# loans            O      | O
# shareholder      O      | O
# loans            O      | O
# affiliate        O      | O
# control          O      | O
# creditor         O      | O
# means            O      | O
# bank             I-ORG  | I-ORG
# special          O      | O
# purpose          O      | O
# project          O      | O
# company          O      | O
# trust            O      | O
# company          O      | O
# mortgage         O      | O
# company          O      | O
# insurance        O      | O
# company          O      | O
# pension          O      | O
# fund             O      | O
# real             O      | O
# estate           O      | O
# investment       O      | O
# trust            O      | O
# lending          O      | O
# financial        O      | O
# institutions     O      | O
# including        O      | O
# indirect         O      | O
# lenders          O      | O
# loan             O      | O
# participants     O      | O
# providing        O      | O
# debt             O      | O
# equity           O      | O
# lease            O      | O
# bond             O      | O
# financing        O      | O
# financial        O      | O
# services         O      | O
# credit           O      | O
# support          O      | O
# credit           O      | O
# enhancement      O      | O
# way              O      | O
# related          O      | O
# construction     O      | O
# works            O      | O
# borrower         I-PER  | I-PER
# obtain           O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# unless           O      | O
# borrower         I-PER  | I-PER
# provides         O      | O
# unconditional    O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# form             O      | O
# acceptable       O      | O
# lender           I-PER  | I-PER
# sole             O      | O
# discretion       O      | O
# borrower         I-PER  | I-PER
# obtains          O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# provide          O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# upon             O      | O
# execution        O      | O
# assignment       O      | O
# assumption       O      | O
# agreement        O      | O
# whereby          O      | O
# borrower         I-PER  | I-PER
# assigns          O      | O
# rights           O      | O
# assignee         O      | O
# assignee         O      | O
# assumes          O      | O
# obligations      O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# successive       O      | O
# assignments      O      | O
# borrower         I-PER  | I-PER
# rights           O      | O
# loan             O      | O
# agreement        O      | O
# remain           O      | O
# subject          O      | O
# article          O      | O
# provided         O      | O
# silicium         I-ORG  | O
# de               I-ORG  | O
# provence         I-ORG  | O
# released         O      | O
# guarantee        O      | O
# provided         O      | O
# satisfaction     O      | O
# obligations      O      | O
# article          O      | O
# result           O      | O
# assignment       O      | O
# occurs           O      | O
# initial          O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# unless           O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# obtained         O      | O
# case             O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# item             O      | O
# apply            O      | O
# lender           I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# without          O      | O
# consent          O      | O
# borrower         I-PER  | I-PER
# event            O      | O
# change           O      | O
# control          O      | O
# lender           I-PER  | I-PER
# sale             O      | O
# substantially    O      | O
# assets           O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# relates          O      | O
# page             O      | O
# december         O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# giving           O      | O
# security         O      | O
# one              O      | O
# party            O      | O
# hereunder        O      | O
# way              O      | O
# diminish         O      | O
# party            O      | O
# rights           O      | O
# obligations      O      | O
# giving           O      | O
# parties          O      | O
# successor        O      | O
# rights           O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# including        O      | O
# amendments       O      | O
# hereto           O      | O
# written          O      | O
# request          O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# cooperate        O      | O
# borrower         I-PER  | I-PER
# creditors        O      | O
# entering         O      | O
# timely           O      | O
# manner           O      | O
# direct           O      | O
# agreements       O      | O
# may              O      | O
# reasonably       O      | O
# necessary        O      | O
# customary        O      | O
# project          O      | O
# financing        O      | O
# works            O      | O
# agreements       O      | O
# may              O      | O
# include          O      | O
# provisions       O      | O
# permit           O      | O
# creditors        O      | O
# event            O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# permit           O      | O
# lender           I-PER  | I-PER
# terminate        O      | O
# loan             O      | O
# agreement        O      | O
# take             O      | O
# loan             O      | O
# agreement        O      | O
# ii               O      | O
# step             O      | O
# rectify          O      | O
# cure             O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# iii              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# whole            O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# constitutes      O      | O
# entire           O      | O
# agreement        O      | O
# parties          O      | O
# respect          O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# herein           O      | O
# stated           O      | O
# instruments      O      | O
# documents        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# hereto           O      | O
# contains         O      | O
# representations  O      | O
# undertakings     O      | O
# agreements       O      | O
# parties          O      | O
# loan             O      | O
# agreement        O      | O
# supersedes       O      | O
# prior            O      | O
# meetings         O      | O
# correspondence   O      | O
# negotiations     O      | O
# parties          O      | O
# representations  O      | O
# warranties       O      | O
# covenants        O      | O
# agreements       O      | O
# collateral       O      | O
# understandings   O      | O
# oral             O      | O
# expressed        O      | O
# implied          O      | O
# kind             O      | O
# parties          O      | O
# hereto           O      | O
# respecting       O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# contained        O      | O
# referred         O      | O
# herein           O      | O
# neither          O      | O
# party            O      | O
# relied           O      | O
# statement        O      | O
# outside          O      | O
# written          O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# variation        O      | O
# loan             O      | O
# agreement        O      | O
# must             O      | O
# writing          O      | O
# signed           O      | O
# behalf           O      | O
# parties          O      | O
# waiver           O      | O
# right            O      | O
# loan             O      | O
# agreement        O      | O
# effective        O      | O
# writing          O      | O
# applies          O      | O
# party            O      | O
# waiver           O      | O
# addressed        O      | O
# circumstances    O      | O
# given            O      | O
# severance        O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# appears          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provisions       O      | O
# will             O      | O
# remain           O      | O
# force            O      | O
# parties          O      | O
# obliged          O      | O
# replace          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# provisions       O      | O
# valid            O      | O
# enforceable      O      | O
# legal            O      | O
# binding          O      | O
# way              O      | O
# new              O      | O
# provisions       O      | O
# differ           O      | O
# little           O      | O
# possible         O      | O
# original         O      | O
# provisions       O      | O
# taking           O      | O
# account          O      | O
# object           O      | O
# purpose          O      | O
# contents         O      | O
# loan             O      | O
# agreement        O      | O
# notices          O      | O
# notice           O      | O
# communication    O      | O
# required         O      | O
# given            O      | O
# loan             O      | O
# agreement        O      | O
# writing          O      | O
# delivered        O      | O
# party            O      | O
# required         O      | O
# receive          O      | O
# notice           O      | O
# communication    O      | O
# address          O      | O
# set              O      | O
# borrower         I-PER  | I-PER
# usine            O      | I-ORG
# de               O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# page             O      | O
# december         O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | O
# attention        O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | I-ORG
# ceo              I-LOC  | O
# lender           I-PER  | I-PER
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-LOC
# massachusetts    I-LOC  | I-LOC
# attention        O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | O
# vice             O      | O
# president        O      | O
# address          O      | O
# relevant         O      | O
# party            O      | O
# may              O      | O
# specify          O      | O
# notice           O      | O
# writing          O      | O
# parties          O      | O
# notice           O      | O
# communication    O      | O
# sent             O      | O
# mail             O      | O
# facsimile        O      | O
# must             O      | O
# confirmed        O      | O
# commercial       O      | O
# courier          O      | O
# notice           O      | O
# communication    O      | O
# deemed           O      | O
# duly             O      | O
# given            O      | O
# delivered        O      | O
# personally       O      | O
# left             O      | O
# address          O      | O
# referred         O      | O
# article          O      | O
# delivered        O      | O
# commercial       O      | O
# courier          O      | O
# date             O      | O
# signature        O      | O
# courier          O      | O
# receipt          O      | O
# sent             O      | O
# fax              O      | O
# time             O      | O
# transmission     O      | O
# sent             O      | O
# mail             O      | O
# time             O      | O
# despatch         O      | O
# deemed           O      | O
# receipt          O      | O
# previous         O      | O
# paragraphs       O      | O
# article          O      | O
# within           O      | O
# business         O      | O
# hours            O      | O
# meaning          O      | O
# pm               O      | O
# monday           O      | O
# friday           O      | O
# day              O      | O
# public           O      | O
# holiday          O      | O
# place            O      | O
# receipt          O      | O
# business         O      | O
# next             O      | O
# starts           O      | O
# place            O      | O
# receipt          O      | O
# confidentiality  O      | O
# party            O      | O
# undertakes       O      | O
# time             O      | O
# loan             O      | O
# agreement        O      | O
# period           O      | O
# five             O      | O
# years            O      | O
# termination      O      | O
# loan             O      | O
# agreement        O      | O
# disclose         O      | O
# person           O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# article          O      | O
# means            O      | O
# knowledge        O      | O
# financial        O      | O
# data             O      | O
# operating        O      | O
# data             O      | O
# trade            O      | O
# secrets          O      | O
# experience       O      | O
# know             O      | O
# information      O      | O
# kinds            O      | O
# whatever         O      | O
# form             O      | O
# technologies     O      | O
# finances         O      | O
# costs            O      | O
# marketing        O      | O
# business         O      | O
# including        O      | O
# limited          O      | O
# term             O      | O
# sheets           O      | O
# notes            O      | O
# analyses         O      | O
# agreements       O      | O
# compilations     O      | O
# studies          O      | O
# interpretations  O      | O
# suchlike         O      | O
# disclosed        O      | O
# behalf           O      | O
# disclosing       O      | O
# party            O      | O
# whether          O      | O
# marked           O      | O
# confidential     O      | O
# information      O      | O
# including        O      | O
# confidential     O      | O
# information      O      | O
# communicated     O      | O
# receiving        O      | O
# party            O      | O
# orally           O      | O
# reduced          O      | O
# writing          O      | O
# exclude          O      | O
# information      O      | O
# becomes          O      | O
# improper         O      | O
# action           O      | O
# inaction         O      | O
# receiving        O      | O
# party            O      | O
# affiliate        O      | O
# agent            O      | O
# consultant       O      | O
# employee         O      | O
# generally        O      | O
# available        O      | O
# public           O      | O
# ii               O      | O
# possession       O      | O
# known            O      | O
# prior            O      | O
# receipt          O      | O
# disclosing       O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iii              O      | O
# rightfully       O      | O
# disclosed        O      | O
# third            O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iv               O      | O
# independently    O      | O
# developed        O      | O
# without          O      | O
# use              O      | O
# confidential     O      | O
# information      O      | O
# disclosing       O      | O
# party            O      | O
# ôøω              O      | O
# party            O      | O
# may              O      | O
# disclose         O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# page             O      | O
# december         O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# need             O      | O
# know             O      | O
# information      O      | O
# purposes         O      | O
# carrying         O      | O
# party            O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# party            O      | O
# ensure           O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# discloses        O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# comply           O      | O
# article          O      | O
# may              O      | O
# required         O      | O
# law              O      | O
# court            O      | O
# order            O      | O
# governmental     O      | O
# regulatory       O      | O
# authority        O      | O
# party            O      | O
# use              O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# french           I-MISC | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# correspondence   O      | O
# notices          O      | O
# written          O      | O
# communications   O      | O
# english          I-MISC | O
# disputes         O      | O
# dispute          O      | O
# arises           O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# directors        O      | O
# senior           O      | O
# representatives  O      | O
# parties          O      | O
# authority        O      | O
# settle           O      | O
# dispute          O      | O
# will             O      | O
# within           O      | O
# ten              O      | O
# days             O      | O
# written          O      | O
# request          O      | O
# one              O      | O
# party            O      | O
# meet             O      | O
# good             O      | O
# faith            O      | O
# effort           O      | O
# resolve          O      | O
# dispute          O      | O
# disputes         O      | O
# arising          O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# resolved         O      | O
# pursuant         O      | O
# article          O      | O
# finally          O      | O
# settled          O      | O
# rules            O      | O
# arbitration      O      | O
# international    O      | I-ORG
# chamber          O      | O
# commerce         O      | I-ORG
# three            O      | O
# arbitrators      O      | O
# appointed        O      | O
# accordance       O      | O
# said             O      | O
# rules            O      | O
# arbitration      O      | O
# conducted        O      | O
# english          I-MISC | I-PER
# seat             O      | O
# paris            I-LOC  | O
# events           O      | O
# default          O      | O
# following        O      | O
# events           O      | O
# considered       O      | O
# events           O      | O
# default          O      | O
# respect          O      | O
# loan             O      | O
# agreement        O      | O
# borrower         I-PER  | I-PER
# default          O      | O
# payment          O      | O
# part             O      | O
# principal        O      | O
# unpaid           O      | O
# accrued          O      | O
# interest         O      | O
# loan             O      | O
# thirty           O      | O
# days             O      | O
# become           O      | O
# due              O      | O
# payable          O      | O
# whether          O      | O
# maturity         O      | O
# date             O      | O
# fixed            O      | O
# prepayment       O      | O
# acceleration     O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# admits           O      | O
# inability        O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# reason           O      | O
# actual           O      | O
# anticipated      O      | O
# financial        O      | O
# difficulties     O      | O
# suspends         O      | O
# making           O      | O
# payments         O      | O
# debts            O      | O
# commences        O      | O
# negotiations     O      | O
# one              O      | O
# creditors        O      | O
# view             O      | O
# rescheduling     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# state            O      | O
# suspension       O      | O
# payments         O      | O
# cessation        O      | O
# des              O      | O
# paiements        O      | O
# within           O      | O
# meaning          O      | O
# article          O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# corporate        O      | O
# action           O      | O
# legal            O      | O
# proceedings      O      | O
# procedures       O      | O
# steps            O      | O
# taken            O      | O
# reason           O      | O
# borrower         I-PER  | I-PER
# financial        O      | O
# difficulties     O      | O
# relation         O      | O
# suspension       O      | O
# payments         O      | O
# moratorium       O      | O
# indebtedness     O      | O
# winding          O      | O
# dissolution      O      | O
# administration   O      | O
# reorganisation   O      | O
# solvent          O      | O
# winding          O      | O
# dissolution      O      | O
# reorganisation   O      | O
# carried          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# unreasonably     O      | O
# withheld         O      | O
# delayed          O      | O
# borrower         I-PER  | I-PER
# composition      O      | O
# compromise       O      | O
# assignment       O      | O
# arrangement      O      | O
# creditor         O      | O
# borrower         I-PER  | I-PER
# page             O      | O
# december         O      | O
# appointment      O      | O
# liquidator       O      | O
# receiver         O      | O
# administrator    O      | O
# administrative   O      | O
# receiver         O      | O
# compulsory       O      | O
# manager          O      | O
# similar          O      | O
# officer          O      | O
# respect          O      | O
# borrower         I-PER  | I-PER
# assets           O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# commences        O      | O
# proceedings      O      | O
# conciliation     O      | O
# accordance       O      | O
# articles         O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# judgment         O      | O
# sauvegarde       O      | I-PER
# redressement     O      | I-PER
# judiciaire       O      | O
# liquidation      O      | O
# judiciaire       O      | O
# entered          O      | O
# relation         O      | O
# borrower         I-PER  | I-PER
# articles         O      | O
# french           I-MISC | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# judgment         O      | O
# entered          O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# fail             O      | O
# observe          O      | O
# perform          O      | O
# obligation       O      | O
# observed         O      | O
# performed        O      | O
# loan             O      | O
# agreement        O      | O
# within           O      | O
# thirty           O      | O
# days             O      | O
# written          O      | O
# notice           O      | O
# lender           I-PER  | I-PER
# perform          O      | O
# observe          O      | O
# obligation       O      | O
# borrower         I-PER  | I-PER
# stops            O      | O
# construction     O      | O
# works            O      | O
# acknowledges     O      | O
# will             O      | O
# unable           O      | O
# unwilling        O      | O
# complete         O      | O
# construction     O      | O
# ...
# process          O      | O
# entries          O      | O
# register         O      | O
# conclusive       O      | O
# binding          O      | O
# purposes         O      | O
# absent           O      | O
# manifest         O      | O
# error            O      | O
# servicer         O      | O
# holders          O      | O
# may              O      | O
# treat            O      | O
# person           O      | O
# entity           O      | O
# whose            O      | O
# name             O      | O
# recorded         O      | O
# register         O      | O
# holder           O      | O
# hereunder        O      | O
# purposes         O      | O
# agreement        O      | O
# register         O      | O
# available        O      | O
# inspection       O      | O
# copying          O      | O
# holder           O      | O
# normal           O      | O
# business         O      | O
# hours            O      | O
# upon             O      | O
# reasonable       O      | O
# prior            O      | O
# notice           O      | O
# servicer         O      | O
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# hereto           O      | O
# caused           O      | O
# agreement        O      | O
# duly             O      | O
# executed         O      | O
# day              O      | O
# year             O      | O
# first            O      | O
# written          O      | O
# pim              O      | O
# ashford          I-ORG  | I-LOC
# venture          I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# investments      O      | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# reit             O      | I-ORG
# operating        O      | O
# lp               O      | O
# delaware         O      | I-LOC
# limited          O      | O
# partnership      O      | O
# sole             O      | O
# member           O      | O
# prisa            O      | O
# iii              O      | O
# op               O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# lp               O      | O
# delaware         O      | I-LOC
# limited          O      | O
# partnership      O      | O
# manager          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# pim              O      | O
# llc              O      | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# sole             O      | O
# member           O      | O
# prudential       O      | O
# investment       O      | O
# management       O      | O
# inc              O      | O
# delaware         O      | I-LOC
# corporation      O      | O
# sole             O      | O
# member           O      | O
# name             O      | O
# james            I-PER  | I-LOC
# walker           O      | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# finance          I-ORG  | I-ORG
# lp               I-ORG  | O
# delaware         O      | I-LOC
# limited          O      | O
# partnership      O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# finance          I-ORG  | I-ORG
# general          I-ORG  | O
# partner          I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# name             O      | O
# david            I-PER  | I-PER
# brooks           I-PER  | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | I-ORG
# servicing        I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | I-LOC
# limited          O      | O
# liability        O      | O
# company          O      | O
# name             O      | O
# david            I-PER  | I-PER
# brooks           I-PER  | I-LOC
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# schedule         O      | O
# loan             O      | O
# documents        O      | O
# source           O      | O
# onecle           O      | I-LOC
# business         O      | O
# contracts        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# crocs            O      | O
# inc              O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# logo             O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# dated            O      | O
# november         O      | O
# entered          O      | O
# among            O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# twenty           O      | O
# five             O      | O
# million          O      | O
# dollars          O      | O
# words            O      | O
# add              O      | O
# minimum          O      | O
# net              O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# covenant         O      | O
# section          O      | O
# loan             O      | O
# agreement        O      | O
# hereby           O      | O
# added            O      | O
# read             O      | O
# full             O      | O
# follows          O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# conditions       O      | O
# precedent        O      | O
# effectiveness    O      | O
# amendment        O      | O
# subject          O      | O
# prior            O      | O
# satisfaction     O      | O
# following        O      | O
# conditions       O      | O
# amendment        O      | O
# bank             I-ORG  | I-ORG
# received         O      | O
# original         O      | O
# amendment        O      | O
# duly             O      | O
# executed         O      | O
# borrower         I-PER  | I-PER
# bank             I-ORG  | I-ORG
# documents        O      | O
# borrower         I-PER  | I-PER
# executed         O      | O
# delivered        O      | O
# bank             I-ORG  | I-ORG
# revolving        O      | O
# note             O      | O
# documents        O      | O
# instruments      O      | O
# bank             I-ORG  | I-ORG
# may              O      | O
# reasonably       O      | O
# require          O      | O
# miscellaneous    O      | O
# survival         O      | O
# representations  O      | O
# warranties       O      | O
# representations  O      | O
# warranties       O      | O
# made             O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# documents        O      | O
# relating         O      | O
# thereto          O      | O
# including        O      | O
# without          O      | O
# limitation       O      | O
# loan             O      | O
# documents        O      | O
# furnished        O      | O
# connection       O      | O
# amendment        O      | O
# survive          O      | O
# execution        O      | O
# delivery         O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# investigation    O      | O
# bank             I-ORG  | I-ORG
# closing          O      | O
# affect           O      | O
# representations  O      | O
# warranties       O      | O
# right            O      | O
# bank             I-ORG  | I-ORG
# rely             O      | O
# thereon          O      | O
# events           O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# aware            O      | O
# events           O      | O
# now              O      | O
# constitute       O      | O
# passage          O      | O
# time             O      | O
# giving           O      | O
# notice           O      | O
# constitute       O      | O
# event            O      | O
# default          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# agreements       O      | O
# documents        O      | O
# instruments      O      | O
# now              O      | O
# hereafter        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# terms            O      | O
# hereof           O      | O
# pursuant         O      | O
# terms            O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# hereby           O      | O
# amended          O      | O
# reference        O      | O
# therein          O      | O
# loan             O      | O
# agreement        O      | O
# mean             O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# loan             O      | O
# agreement        O      | O
# remains          O      | O
# effect           O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# remain           O      | O
# full             O      | O
# force            O      | O
# effect           O      | O
# borrower         I-PER  | I-PER
# ratifies         O      | O
# confirms         O      | O
# agreements       O      | O
# covenants        O      | O
# contained        O      | O
# therein          O      | O
# borrower         I-PER  | I-PER
# hereby           O      | O
# confirms         O      | O
# giving           O      | O
# effect           O      | O
# amendment        O      | O
# event            O      | O
# default          O      | O
# default          O      | O
# exists           O      | O
# date             O      | O
# severability     O      | O
# provision        O      | O
# amendment        O      | O
# held             O      | O
# court            O      | O
# competent        O      | O
# jurisdiction     O      | O
# invalid          O      | O
# unenforceable    O      | O
# impair           O      | O
# invalidate       O      | O
# remainder        O      | O
# amendment        O      | O
# effect           O      | O
# thereof          O      | O
# confined         O      | O
# provision        O      | O
# held             O      | O
# invalid          O      | O
# unenforceable    O      | O
# applicable       O      | O
# law              O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# executed         O      | O
# pursuant         O      | O
# hereto           O      | O
# deemed           O      | O
# made             O      | O
# performable      O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# laws             O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# successors       O      | O
# assigns          O      | O
# amendment        O      | O
# binding          O      | O
# upon             O      | O
# inure            O      | O
# benefit          O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# respective       O      | O
# successors       O      | O
# assigns          O      | O
# provided         O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# rights           O      | O
# obligations      O      | O
# hereunder        O      | O
# without          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# bank             I-ORG  | I-ORG
# counterparts     O      | O
# amendment        O      | O
# may              O      | O
# executed         O      | O
# one              O      | O
# counterparts     O      | O
# executed         O      | O
# deemed           O      | O
# original         O      | O
# taken            O      | O
# together         O      | O
# constitute       O      | O
# one              O      | O
# instrument       O      | O
# headings         O      | O
# headings         O      | O
# captions         O      | O
# arrangements     O      | O
# used             O      | O
# amendment        O      | O
# convenience      O      | O
# affect           O      | O
# interpretation   O      | O
# amendment        O      | O
# oral             O      | O
# agreements       O      | O
# amendment        O      | O
# together         O      | O
# loan             O      | O
# documents        O      | O
# written          O      | O
# represents       O      | O
# final            O      | O
# agreement        O      | O
# lenders          O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# contradicted     O      | O
# evidence         O      | O
# prior            O      | O
# contemporaneous  O      | O
# subsequent       O      | O
# oral             O      | O
# agreements       O      | O
# parties          O      | O
# unwritten        O      | O
# oral             O      | O
# agreements       O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# entered          O      | O
# amendment        O      | O
# respective       O      | O
# duly             O      | O
# authorized       O      | O
# officers         O      | O
# date             O      | O
# first            O      | O
# written          O      | O
# crocs            O      | O
# inc              O      | O
# peter            I-PER  | I-PER
# case             I-PER  | O
# peter            I-PER  | I-PER
# case             I-PER  | O
# title            O      | O
# chief            O      | I-ORG
# financial        O      | I-ORG
# officer          O      | O
# address          O      | O
# monarch          I-LOC  | I-LOC
# park             I-LOC  | I-LOC
# place            I-LOC  | O
# niwot            I-LOC  | I-ORG
# colorado         I-LOC  | I-LOC
# attention        O      | O
# keith            I-PER  | I-PER
# love             I-PER  | O
# treasury         O      | O
# manager          O      | O
# telecopier       O      | I-ORG
# telephone        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# douglas          I-PER  | I-LOC
# lambell          O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# title            O      | O
# vice             O      | O
# president        O      | O
# address          O      | O
# street           I-LOC  | I-LOC
# floor            I-LOC  | I-LOC
# san              I-LOC  | O
# diego            I-LOC  | O
# california       I-LOC  | I-LOC
# attention        O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# vp               O      | O
# telecopier       O      | I-ORG
# telephone        O      | O
# source           O      | O
# onecle           O      | I-LOC
# business         O      | O
# contracts        O      | O

# %%
plot_history(history_2)

# %% [markdown]
# With a training accuracy reaching around 99% and a corresponding training loss reaching 0.02, the model exhibits robust learning. This success extends to the validation phase, where an accuracy of about 98.5% is achieved, confirming the model's ability to generalize effectively. The associated validation loss of approximately 0.05 further underscores the model's stable performance, indicating reliable generalization without overfitting. These findings affirm the model's consistent and reliable behavior across both training and validation stages.

# %%
print(classification_report(y_true_2, y_pred_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.98      4548
#            1       0.42      0.56      0.48        61
#            2       0.97      0.90      0.93       192
#            3       0.00      0.00      0.00         7
#            4       0.42      0.34      0.38        97
#
#     accuracy                           0.96      4905
#    macro avg       0.56      0.56      0.55      4905
# weighted avg       0.96      0.96      0.96      4905
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning:
#
# Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.

# %% [markdown]
# Examining the classification report, the model delivers notable performance, particularly in classifying the **O** NER tag. For the minority classes (**I-PER**, **I-LOC**, **I-ORG**), the precision and recall values vary, indicating a nuanced performance. Specifically, **I-PER** exhibits the highest precision, while **I-ORG** presents lower precision and recall values.

# %%
plot_confusion_matrix(y_pred_2, y_true_2, ner_labels)

# %% [markdown]
# From the matrix strong diagonal elements can be observed, especially for the **O** and the **I-PER** NER tags, indicating high correctness in predictions for these categories. However, off-diagonal elements reveal still areas where the model encounters challenges.

# %% [markdown]
# ## Token Ordinal Econding (NO I-MISC)

# %% [markdown]
# In this variant of the model, a new strategy is employed to address the limited instances of the **I-MISC** NER tag, which appears only seven times in the dataset. Since neither of the two preceding models made any predictions for **I-MISC**, in the current model these instances are reclassified as **O**. The objective is to identify potential improvements in overall classification accuracy.

# %% [markdown]
# The operations of splitting the dataset into training, validation and test sets are the same as the previous models. Subsequently, the *Tokenizer* is utilized to convert the raw text data into sequences of numerical values, and one-hot encoding is employed to represent the NER tag labels. These steps align with the preprocessing steps undertaken in the previous two models, ensuring a coherent and standardized approach to data preparation.

# %%
# %%capture
norm_df_nomisc = norm_df[['id','ner_tags']]
norm_df_nomisc['ner_tags'][norm_df_nomisc['ner_tags'] == 'I-MISC']='O'

df_test_nomisc = norm_df_test[['id','ner_tags']]
df_test_nomisc['ner_tags'][df_test_nomisc['ner_tags'] == 'I-MISC'] = 'O'

raw_train_nomisc, raw_valid_nomisc, ner_train_nomisc, ner_valid_nomisc = train_test_split(norm_df_nomisc['id'],
                                                                                          norm_df_nomisc['ner_tags'],
                                                                                          test_size = 0.2,
                                                                                          random_state = 22)
raw_test_nomisc = df_test_nomisc['id']
ner_test_nomisc = df_test_nomisc['ner_tags']

ner_labels_nomisc = set()
ner_labels_nomisc.add('I-PER')
ner_labels_nomisc.add('I-LOC')
ner_labels_nomisc.add('I-ORG')
ner_labels_nomisc.add('O')

raw_train_nomisc = raw_train_nomisc.tolist()
raw_valid_nomisc = raw_valid_nomisc.tolist()
raw_test_nomisc = raw_test_nomisc.tolist()

tok_nomisc = Tokenizer()
tok_nomisc.fit_on_texts(raw_train_nomisc + raw_valid_nomisc + raw_test_nomisc)

train_sequences_nomisc = tok_nomisc.texts_to_sequences(raw_train_nomisc)
valid_sequences_nomisc = tok_nomisc.texts_to_sequences(raw_valid_nomisc)
test_sequences_nomisc = tok_nomisc.texts_to_sequences(raw_test_nomisc)

tag2idx = {tag: idx for idx, tag in enumerate(ner_labels_nomisc)}
idx2tag = {idx: tag for tag, idx in tag2idx.items()}

ner_train_sequences_nomisc = [tag2idx[tag] for tag in ner_train_nomisc]
ner_valid_sequences_nomisc = [tag2idx[tag] for tag in ner_valid_nomisc]
ner_test_sequences_nomisc = [tag2idx[tag] for tag in ner_test_nomisc]

y_train_nomisc = to_categorical(ner_train_sequences_nomisc, num_classes = len(ner_labels_nomisc), dtype = 'int32')
y_valid_nomisc = to_categorical(ner_valid_sequences_nomisc, num_classes = len(ner_labels_nomisc), dtype = 'int32')
y_test_nomisc = to_categorical(ner_test_sequences_nomisc, num_classes = len(ner_labels_nomisc), dtype = 'int32')

X_train_nomisc = np.array(train_sequences_nomisc)
X_valid_nomisc = np.array(valid_sequences_nomisc)
X_test_nomisc = np.array(test_sequences_nomisc)
y_train_nomisc = np.array(y_train_nomisc)
y_valid_nomisc = np.array(y_valid_nomisc)
y_test_nomisc = np.array(y_test_nomisc)

# %%
word_index_nomisc = tok_nomisc.word_index
print('Found %s unique tokens.' % len(word_index_nomisc))
# Out:
# Found 2845 unique tokens.

# %% [markdown]
# ## Model (NO I-MISC)

# %% [markdown]
# The model is constructed maintaining consistency with the previous ones. The distinction lies in the configuration of the neural network, where the output layer is adjusted to accommodate four classes instead of the previous five. This modification aligns with the exclusion of the **I-MISC** category. The remaining architectural components  remain unchanged.

# %%
max_features = 10000
num_words_nomisc = min(max_features, len(word_index_nomisc)) + 1
print("NO-MISC vocabulary size: ",num_words_nomisc)

embedding_dim = 100

# first create a matrix of zeros, this is our embedding matrix
embedding_matrix = np.zeros((num_words_nomisc, embedding_dim))

# for each word in our tokenizer lets try to find that word in our w2v model
for word, i in word_index_nomisc.items():
    if i > max_features:
        continue
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        # we found the word - add that words vector to the matrix
        embedding_matrix[i] = embedding_vector
    else:
        # doesn't exist, assign a random vector
        embedding_matrix[i] = np.random.randn(embedding_dim)
# Out:
# NO-MISC vocabulary size:  2846

# %%
lstm_out = 200

model = Sequential()
model.add(Embedding(num_words_nomisc, embedding_dim,
                    embeddings_initializer = Constant(embedding_matrix),
                    input_length=X_train_nomisc.shape[1]))
model.add(Bidirectional(LSTM(lstm_out, return_sequences = True)))
model.add(LSTM(lstm_out))
model.add(Dense(lstm_out, activation = 'relu'))
model.add(Dense(4, activation = 'softmax'))
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 1, 100)            284600
#
#  bidirectional_2 (Bidirecti  (None, 1, 400)            481600
#  onal)
#
#  lstm_5 (LSTM)               (None, 200)               480800
#
#  dense_4 (Dense)             (None, 200)               40200
#
#  dense_5 (Dense)             (None, 4)                 804
#
# =================================================================
# Total params: 1288004 (4.91 MB)
# Trainable params: 1288004 (4.91 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
from keras.utils import plot_model

plot_model(model, show_shapes=True, show_layer_names=True)

# %%
batch_size = 64
history_nomisc = model.fit(X_train_nomisc, y_train_nomisc, epochs=50, batch_size = batch_size, verbose = 1,
                    validation_data = (X_valid_nomisc, y_valid_nomisc), callbacks = [early_stopping])
# Out:
# Epoch 1/50
# 224/224 [==============================] - 11s 20ms/step - loss: 0.1624 - accuracy: 0.9642 - val_loss: 0.0786 - val_accuracy: 0.9799
# Epoch 2/50
# 224/224 [==============================] - 2s 10ms/step - loss: 0.0559 - accuracy: 0.9839 - val_loss: 0.0648 - val_accuracy: 0.9818
# Epoch 3/50
# 224/224 [==============================] - 2s 10ms/step - loss: 0.0417 - accuracy: 0.9869 - val_loss: 0.0611 - val_accuracy: 0.9841
# Epoch 4/50
# 224/224 [==============================] - 3s 13ms/step - loss: 0.0353 - accuracy: 0.9887 - val_loss: 0.0596 - val_accuracy: 0.9832
# Epoch 5/50
# 224/224 [==============================] - 4s 18ms/step - loss: 0.0310 - accuracy: 0.9898 - val_loss: 0.0639 - val_accuracy: 0.9827
# Epoch 6/50
# 224/224 [==============================] - 2s 10ms/step - loss: 0.0297 - accuracy: 0.9896 - val_loss: 0.0703 - val_accuracy: 0.9810
# Epoch 7/50
# 224/224 [==============================] - 2s 10ms/step - loss: 0.0270 - accuracy: 0.9899 - val_loss: 0.0670 - val_accuracy: 0.9846
# Epoch 8/50
# 224/224 [==============================] - 2s 10ms/step - loss: 0.0270 - accuracy: 0.9895 - val_loss: 0.0720 - val_accuracy: 0.9838

# %%
y_pred_nomisc = model.predict(X_test_nomisc)
y_pred_nomisc = np.argmax(y_pred_nomisc, axis=-1)
y_true_nomisc = np.argmax(y_test_nomisc, axis=-1)

for idx in range(len(X_test_nomisc)):
    word_idx = int(X_test_nomisc[idx])
    true_tag_nomisc = idx2tag[y_true_nomisc[idx]]
    pred_tag_nomisc = idx2tag[y_pred_nomisc[idx]]

    print(f'{tok.index_word[word_idx]:15}  {true_tag_nomisc:6} | {pred_tag_nomisc}')
# Out:
# 154/154 [==============================] - 1s 3ms/step
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# silicium         I-ORG  | I-ORG
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              I-ORG  | O
# december         O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# logo             O      | O
# silicium         I-ORG  | I-ORG
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# sas              I-ORG  | I-ORG
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# herbert          I-PER  | I-PER
# smith            I-PER  | O
# llp              O      | O
# page             O      | O
# december         O      | O
# table            O      | O
# contents         O      | O
# clause           O      | O
# headings         O      | O
# page             O      | O
# interpretation   O      | O
# loan             O      | O
# interest         O      | O
# redemption       O      | O
# early            O      | O
# redemptions      O      | O
# representations  O      | O
# undertakings     O      | O
# subordination    O      | O
# costs            O      | O
# partial          O      | O
# payments         O      | O
# assignment       O      | O
# whole            O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# severance        O      | O
# notices          O      | O
# confidentiality  O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# disputes         O      | O
# page             O      | O
# december         O      | O
# subordinated     O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# made             O      | O
# december         O      | O
# silicium         I-ORG  | I-ORG
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# private          O      | O
# company          O      | O
# limited          O      | O
# liability        O      | O
# incorporated     O      | O
# laws             O      | O
# france           I-LOC  | I-LOC
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# usine            I-LOC  | O
# de               I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | I-LOC
# represented      O      | O
# mr               O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | O
# hereinafter      O      | O
# referred         O      | O
# evergreen        I-ORG  | O
# solar            I-ORG  | O
# inc              I-ORG  | O
# company          O      | O
# incorporated     O      | O
# delaware         O      | O
# registered       O      | O
# number           O      | O
# whose            O      | O
# registered       O      | O
# office           O      | O
# situated         O      | O
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-ORG
# massachusetts    I-LOC  | I-LOC
# represented      O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | I-ORG
# hereinafter      O      | O
# referred         O      | O
# hereinafter      O      | O
# referred         O      | O
# severally        O      | O
# jointly          O      | O
# whereas          O      | O
# borrower         I-PER  | I-PER
# intends          O      | O
# develop          O      | O
# plant            O      | O
# france           I-LOC  | I-LOC
# production       O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# entered          O      | O
# agreement        O      | O
# sale             O      | O
# purchase         O      | O
# solar            O      | O
# grade            O      | O
# silicon          O      | I-ORG
# date             O      | O
# hereof           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# agreed           O      | O
# consideration    O      | O
# borrower         I-PER  | I-PER
# entering         O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# lender           I-PER  | I-PER
# lender           I-PER  | I-PER
# make             O      | O
# available        O      | O
# borrower         I-PER  | I-PER
# way              O      | O
# subordinated     O      | O
# loan             O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# parties          O      | O
# wish             O      | O
# set              O      | O
# terms            O      | O
# conditions       O      | O
# loan             O      | O
# agreement        O      | O
# now              O      | O
# parties          O      | O
# agree            O      | O
# follows          O      | O
# interpretation   O      | O
# loan             O      | O
# agreement        O      | O
# unless           O      | O
# specified        O      | O
# context          O      | O
# requires         O      | O
# words            O      | O
# importing        O      | O
# singular         O      | O
# include          O      | O
# plural           O      | O
# vice             O      | O
# versa            O      | O
# words            O      | O
# importing        O      | O
# gender           O      | O
# include          O      | O
# genders          O      | O
# words            O      | O
# importing        O      | O
# whole            O      | O
# treated          O      | O
# including        O      | O
# reference        O      | O
# part             O      | O
# whole            O      | O
# reference        O      | O
# article          O      | O
# relevant         O      | O
# article          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# modified         O      | O
# amended          O      | O
# varied           O      | O
# supplemented     O      | O
# replaced         O      | O
# time             O      | O
# time             O      | O
# reference        O      | O
# provision        O      | O
# law              O      | O
# reference        O      | O
# provision        O      | O
# extended         O      | O
# applied          O      | O
# amended          O      | O
# consolidated     O      | O
# re               O      | O
# enacted          O      | O
# application      O      | O
# thereof          O      | O
# modified         O      | O
# time             O      | O
# time             O      | O
# construed        O      | O
# including        O      | O
# reference        O      | O
# order            O      | O
# instrument       O      | O
# regulation       O      | O
# subordinate      O      | O
# legislation      O      | O
# time             O      | O
# time             O      | O
# made             O      | O
# except           O      | O
# provided         O      | O
# loan             O      | O
# agreement        O      | O
# page             O      | O
# december         O      | O
# references       O      | O
# words            O      | O
# ôøω              O      | O
# include          O      | O
# ôøω              O      | O
# ôøω              O      | O
# including        O      | O
# ôøω              O      | O
# construed        O      | O
# without          O      | O
# limitation       O      | O
# reference        O      | O
# writing          O      | O
# written          O      | O
# includes         O      | O
# faxes            O      | O
# mail             O      | O
# headings         O      | O
# used             O      | O
# loan             O      | O
# agreement        O      | O
# affect           O      | O
# construction     O      | O
# interpretation   O      | O
# words            O      | O
# phrases          O      | O
# defined          O      | O
# part             O      | O
# loan             O      | O
# agreement        O      | O
# bear             O      | O
# meanings         O      | O
# throughout       O      | O
# agreement        O      | O
# wherever         O      | O
# loan             O      | O
# agreement        O      | O
# provision        O      | O
# made             O      | O
# giving           O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# person           O      | O
# unless           O      | O
# stated           O      | O
# unreasonably     O      | O
# withheld         O      | O
# notice           O      | O
# consent          O      | O
# approval         O      | O
# writing          O      | O
# word             O      | O
# ôøω              O      | O
# notify           O      | O
# ôøω              O      | O
# construed        O      | O
# accordingly      O      | O
# notices          O      | O
# served           O      | O
# parties          O      | O
# designated       O      | O
# representative   O      | O
# registered       O      | O
# address          O      | O
# party            O      | O
# address          O      | O
# party            O      | O
# may              O      | O
# notify           O      | O
# party            O      | O
# time             O      | O
# time             O      | O
# loan             O      | O
# lender           I-PER  | I-PER
# grants           O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# total            O      | O
# principal        O      | O
# amount           O      | O
# thirty           O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# disbursed        O      | O
# borrower         I-PER  | I-PER
# two              O      | O
# instalments      O      | O
# follows          O      | O
# first            O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# november         O      | O
# second           O      | O
# instalment       O      | O
# fifteen          O      | O
# million          O      | O
# euros            O      | O
# eur              O      | O
# paid             O      | O
# later            O      | O
# january          O      | O
# actual           O      | O
# disbursement     O      | O
# date             O      | O
# last             O      | O
# instalment       O      | O
# loan             O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# paid             O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# account          O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# follows          O      | O
# bank             I-ORG  | I-ORG
# ing              O      | I-PER
# belgium          I-LOC  | I-LOC
# succursale       O      | I-ORG
# en               O      | I-LOC
# france           I-LOC  | I-LOC
# branch           O      | O
# immeuble         I-LOC  | I-LOC
# les              I-LOC  | I-ORG
# caryatides       I-LOC  | I-ORG
# boulevard        I-LOC  | I-LOC
# carnot           I-LOC  | I-PER
# lille            I-LOC  | O
# cedex            I-LOC  | O
# account          O      | O
# number           O      | O
# iban             O      | I-LOC
# number           O      | O
# bic              O      | O
# number           O      | O
# ingbfrpp         O      | O
# code             O      | O
# guichet          O      | I-ORG
# du               O      | I-ORG
# compte           O      | I-PER
# cle              O      | O
# rib              O      | O
# bank             I-ORG  | I-ORG
# account          O      | O
# may              O      | O
# nominated        O      | O
# time             O      | O
# time             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# pursuant         O      | O
# article          O      | O
# loan             O      | O
# used             O      | O
# borrower         I-PER  | I-PER
# solely           O      | O
# finance          O      | O
# works            O      | O
# arising          O      | O
# relating         O      | O
# construction     O      | O
# borrower         I-PER  | I-PER
# plant            O      | O
# avoidance        O      | O
# doubt            O      | O
# loan             O      | O
# used             O      | O
# increase         O      | O
# management       O      | O
# remuneration     O      | O
# repayment        O      | O
# indebtedness     O      | O
# borrowed         O      | O
# money            O      | O
# capital          O      | O
# distribution     O      | O
# borrower         I-PER  | I-PER
# equity           O      | O
# holders          O      | O
# interest         O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# effective        O      | O
# date             O      | O
# pay              O      | O
# interest         O      | O
# arrears          O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# outstanding      O      | O
# time             O      | O
# time             O      | O
# interest         O      | O
# calculated       O      | O
# rate             O      | O
# three            O      | O
# percent          O      | O
# per              O      | O
# calendar         O      | O
# year             O      | O
# compounded       O      | O
# annually         O      | O
# actual           O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# plus             O      | O
# accrued          O      | O
# interest         O      | O
# amounts          O      | O
# due              O      | O
# hereunder        O      | O
# provided         O      | O
# upon             O      | O
# failure          O      | O
# repay            O      | O
# part             O      | O
# loan             O      | O
# due              O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# set              O      | O
# forth            O      | O
# page             O      | O
# december         O      | O
# clause           O      | O
# loan             O      | O
# agreement        O      | O
# foregoing        O      | O
# rate             O      | O
# increase         O      | O
# amount           O      | O
# equal            O      | O
# twelve           O      | O
# month            O      | O
# euribor          O      | I-ORG
# rate             O      | O
# determined       O      | O
# business         O      | O
# day              O      | O
# preceding        O      | O
# default          O      | O
# reported         O      | O
# wall             I-LOC  | O
# street           I-LOC  | I-LOC
# journal          O      | I-ORG
# plus             O      | O
# three            O      | O
# unpaid           O      | O
# amount           O      | O
# means            O      | O
# period           O      | O
# days             O      | O
# case             O      | O
# may              O      | O
# beginning        O      | O
# january          O      | O
# ending           O      | O
# december         O      | O
# interest         O      | O
# calculated       O      | O
# basis            O      | O
# actual           O      | O
# number           O      | O
# days             O      | O
# elapsed          O      | O
# borrower         I-PER  | I-PER
# repay            O      | O
# loan             O      | O
# interest         O      | O
# accrued          O      | O
# hereunder        O      | O
# date             O      | O
# falling          O      | O
# five             O      | O
# years            O      | O
# effective        O      | O
# date             O      | O
# save             O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# prepay           O      | O
# part             O      | O
# loan             O      | O
# accordance       O      | O
# article          O      | O
# provided         O      | O
# event            O      | O
# lender           I-PER  | I-PER
# terminates       O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# pursuant         O      | O
# article          O      | O
# thereof          O      | O
# repayment        O      | O
# date             O      | O
# effective        O      | O
# date             O      | O
# termination      O      | O
# interest         O      | O
# due              O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# first            O      | O
# second           O      | O
# instalments      O      | O
# payable          O      | O
# whole            O      | O
# repayment        O      | O
# date             O      | O
# purposes         O      | O
# articles         O      | O
# et               O      | O
# seq              O      | I-ORG
# french           O      | O
# code             O      | O
# de               O      | O
# la               O      | I-LOC
# consommation     O      | O
# lender           I-PER  | I-PER
# hereby           O      | O
# informs          O      | O
# borrower         I-PER  | I-PER
# rate             O      | O
# taux             O      | O
# effectif         O      | O
# global           O      | I-ORG
# loan             O      | O
# three            O      | O
# percent          O      | O
# payments         O      | O
# made             O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# euros            O      | O
# immediately      O      | O
# available        O      | O
# cleared          O      | O
# funds            O      | O
# electronic       O      | O
# transfer         O      | O
# account          O      | O
# held             O      | O
# silicon          I-LOC  | I-ORG
# valley           I-LOC  | I-ORG
# bank             I-ORG  | I-ORG
# account          O      | O
# number           O      | O
# swift            O      | O
# code             O      | O
# credit           O      | O
# early            O      | O
# repayment        O      | O
# borrower         I-PER  | I-PER
# times            O      | O
# allowed          O      | O
# prepay           O      | O
# loan             O      | O
# whole            O      | O
# part             O      | O
# without          O      | O
# premium          O      | O
# penalty          O      | O
# provided         O      | O
# whole            O      | O
# multiples        O      | O
# eur              O      | O
# ten              O      | O
# days             O      | O
# prior            O      | O
# written          O      | O
# notice           O      | O
# delivered        O      | O
# lender           I-PER  | I-PER
# notwithstanding  O      | O
# provisions       O      | O
# clause           O      | O
# early            O      | O
# redemption       O      | O
# agreement        O      | O
# include          O      | O
# accrued          O      | O
# interest         O      | O
# amount           O      | O
# prepaid          O      | O
# representations  O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# represents       O      | O
# warrants         O      | O
# company          O      | O
# duly             O      | O
# incorporated     O      | O
# validly          O      | O
# existing         O      | O
# laws             O      | O
# jurisdiction     O      | O
# incorporation    O      | O
# obligations      O      | O
# expressed        O      | O
# assumed          O      | O
# valid            O      | O
# binding          O      | O
# obligations      O      | O
# entry            O      | O
# performance      O      | O
# loan             O      | O
# agreement        O      | O
# will             O      | O
# conflict         O      | O
# provision        O      | O
# law              O      | O
# regulation       O      | O
# applicable       O      | O
# constitutional   O      | O
# documents        O      | O
# agreement        O      | O
# binding          O      | O
# upon             O      | O
# assets           O      | O
# power            O      | O
# enter            O      | O
# perform          O      | O
# deliver          O      | O
# loan             O      | O
# agreement        O      | O
# transactions     O      | O
# contemplated     O      | O
# therein          O      | O
# undertakings     O      | O
# except           O      | O
# stated           O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# hereby           O      | O
# undertakes       O      | O
# things           O      | O
# necessary        O      | O
# maintain         O      | O
# corporate        O      | O
# existence        O      | O
# page             O      | O
# december         O      | O
# obtain           O      | O
# maintain         O      | O
# comply           O      | O
# terms            O      | O
# authorisation    O      | O
# required         O      | O
# applicable       O      | O
# law              O      | O
# regulation       O      | O
# enable           O      | O
# carry            O      | O
# activities       O      | O
# ii               O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# comply           O      | O
# applicable       O      | O
# laws             O      | O
# regulations      O      | O
# subordination    O      | O
# event            O      | O
# insolvency       O      | O
# proceedings      O      | O
# initiated        O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# event            O      | O
# moratorium       O      | O
# debts            O      | O
# borrower         I-PER  | I-PER
# proposed         O      | O
# composition      O      | O
# assignment       O      | O
# arrangement      O      | O
# creditors        O      | O
# obligation       O      | O
# repay            O      | O
# outstanding      O      | O
# amount           O      | O
# loan             O      | O
# subordinated     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# lending          O      | O
# financial        O      | O
# institution      O      | O
# way              O      | O
# related          O      | O
# works            O      | O
# present          O      | O
# future           O      | O
# notwithstanding  O      | O
# whether          O      | O
# indebtedness     O      | O
# recoverable      O      | O
# process          O      | O
# law              O      | O
# conditional      O      | O
# unconditional    O      | O
# financial        O      | O
# loans            O      | O
# manufacturer     O      | O
# loans            O      | O
# shareholder      O      | O
# loans            O      | O
# affiliate        O      | O
# control          O      | O
# creditor         O      | O
# means            O      | O
# bank             I-ORG  | I-ORG
# special          O      | O
# purpose          O      | O
# project          O      | O
# company          O      | O
# trust            O      | O
# company          O      | O
# mortgage         O      | O
# company          O      | O
# insurance        O      | O
# company          O      | O
# pension          O      | O
# fund             O      | O
# real             O      | O
# estate           O      | O
# investment       O      | O
# trust            O      | O
# lending          O      | O
# financial        O      | O
# institutions     O      | O
# including        O      | O
# indirect         O      | O
# lenders          O      | O
# loan             O      | O
# participants     O      | O
# providing        O      | O
# debt             O      | O
# equity           O      | O
# lease            O      | O
# bond             O      | O
# financing        O      | O
# financial        O      | O
# services         O      | O
# credit           O      | O
# support          O      | O
# credit           O      | O
# enhancement      O      | O
# way              O      | O
# related          O      | O
# construction     O      | O
# works            O      | O
# borrower         I-PER  | I-PER
# obtain           O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# unless           O      | O
# borrower         I-PER  | I-PER
# provides         O      | O
# unconditional    O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# form             O      | O
# acceptable       O      | O
# lender           I-PER  | I-PER
# sole             O      | O
# discretion       O      | O
# borrower         I-PER  | I-PER
# obtains          O      | O
# lender           I-PER  | I-PER
# prior            O      | O
# written          O      | O
# consent          O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# encumbrance      O      | O
# sub              O      | O
# clause           O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# provide          O      | O
# repayment        O      | O
# guarantee        O      | O
# lender           I-PER  | I-PER
# borrower         I-PER  | I-PER
# released         O      | O
# obligation       O      | O
# hereunder        O      | O
# upon             O      | O
# execution        O      | O
# assignment       O      | O
# assumption       O      | O
# agreement        O      | O
# whereby          O      | O
# borrower         I-PER  | I-PER
# assigns          O      | O
# rights           O      | O
# assignee         O      | O
# assignee         O      | O
# assumes          O      | O
# obligations      O      | O
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# successive       O      | O
# assignments      O      | O
# borrower         I-PER  | I-PER
# rights           O      | O
# loan             O      | O
# agreement        O      | O
# remain           O      | O
# subject          O      | O
# article          O      | O
# provided         O      | O
# silicium         I-ORG  | I-ORG
# de               I-ORG  | O
# provence         I-ORG  | I-LOC
# released         O      | O
# guarantee        O      | O
# provided         O      | O
# satisfaction     O      | O
# obligations      O      | O
# article          O      | O
# result           O      | O
# assignment       O      | O
# occurs           O      | O
# initial          O      | O
# assignment       O      | O
# borrower         I-PER  | I-PER
# unless           O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# obtained         O      | O
# case             O      | O
# borrower         I-PER  | I-PER
# released         O      | O
# item             O      | O
# apply            O      | O
# lender           I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# without          O      | O
# consent          O      | O
# borrower         I-PER  | I-PER
# event            O      | O
# change           O      | O
# control          O      | O
# lender           I-PER  | I-PER
# sale             O      | O
# substantially    O      | O
# assets           O      | O
# lender           I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# relates          O      | O
# page             O      | O
# december         O      | O
# assignment       O      | O
# transfer         O      | O
# mortgage         O      | O
# charge           O      | O
# pledge           O      | O
# giving           O      | O
# security         O      | O
# one              O      | O
# party            O      | O
# hereunder        O      | O
# way              O      | O
# diminish         O      | O
# party            O      | O
# rights           O      | O
# obligations      O      | O
# giving           O      | O
# parties          O      | O
# successor        O      | O
# rights           O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# including        O      | O
# amendments       O      | O
# hereto           O      | O
# written          O      | O
# request          O      | O
# borrower         I-PER  | I-PER
# lender           I-PER  | I-PER
# cooperate        O      | O
# borrower         I-PER  | I-PER
# creditors        O      | O
# entering         O      | O
# timely           O      | O
# manner           O      | O
# direct           O      | O
# agreements       O      | O
# may              O      | O
# reasonably       O      | O
# necessary        O      | O
# customary        O      | O
# project          O      | O
# financing        O      | O
# works            O      | O
# agreements       O      | O
# may              O      | O
# include          O      | O
# provisions       O      | O
# permit           O      | O
# creditors        O      | O
# event            O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# silicon          O      | I-ORG
# agreement        O      | O
# permit           O      | O
# lender           I-PER  | I-PER
# terminate        O      | O
# loan             O      | O
# agreement        O      | O
# take             O      | O
# loan             O      | O
# agreement        O      | O
# ii               O      | O
# step             O      | O
# rectify          O      | O
# cure             O      | O
# breach           O      | O
# loan             O      | O
# agreement        O      | O
# iii              O      | O
# assign           O      | O
# transfer         O      | O
# loan             O      | O
# agreement        O      | O
# whole            O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# constitutes      O      | O
# entire           O      | O
# agreement        O      | O
# parties          O      | O
# respect          O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# herein           O      | O
# stated           O      | O
# instruments      O      | O
# documents        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# hereto           O      | O
# contains         O      | O
# representations  O      | O
# undertakings     O      | O
# agreements       O      | O
# parties          O      | O
# loan             O      | O
# agreement        O      | O
# supersedes       O      | O
# prior            O      | O
# meetings         O      | O
# correspondence   O      | O
# negotiations     O      | O
# parties          O      | O
# representations  O      | O
# warranties       O      | O
# covenants        O      | O
# agreements       O      | O
# collateral       O      | O
# understandings   O      | O
# oral             O      | O
# expressed        O      | O
# implied          O      | O
# kind             O      | O
# parties          O      | O
# hereto           O      | O
# respecting       O      | O
# subject          O      | O
# matter           O      | O
# hereof           O      | O
# except           O      | O
# contained        O      | O
# referred         O      | O
# herein           O      | O
# neither          O      | O
# party            O      | O
# relied           O      | O
# statement        O      | O
# outside          O      | O
# written          O      | O
# agreement        O      | O
# variation        O      | O
# waiver           O      | O
# variation        O      | O
# loan             O      | O
# agreement        O      | O
# must             O      | O
# writing          O      | O
# signed           O      | O
# behalf           O      | O
# parties          O      | O
# waiver           O      | O
# right            O      | O
# loan             O      | O
# agreement        O      | O
# effective        O      | O
# writing          O      | O
# applies          O      | O
# party            O      | O
# waiver           O      | O
# addressed        O      | O
# circumstances    O      | O
# given            O      | O
# severance        O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# appears          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provisions       O      | O
# will             O      | O
# remain           O      | O
# force            O      | O
# parties          O      | O
# obliged          O      | O
# replace          O      | O
# invalid          O      | O
# unenforceable    O      | O
# illegal          O      | O
# non              O      | O
# binding          O      | O
# provision        O      | O
# loan             O      | O
# agreement        O      | O
# part             O      | O
# provision        O      | O
# provisions       O      | O
# valid            O      | O
# enforceable      O      | O
# legal            O      | O
# binding          O      | O
# way              O      | O
# new              O      | O
# provisions       O      | O
# differ           O      | O
# little           O      | O
# possible         O      | O
# original         O      | O
# provisions       O      | O
# taking           O      | O
# account          O      | O
# object           O      | O
# purpose          O      | O
# contents         O      | O
# loan             O      | O
# agreement        O      | O
# notices          O      | O
# notice           O      | O
# communication    O      | O
# required         O      | O
# given            O      | O
# loan             O      | O
# agreement        O      | O
# writing          O      | O
# delivered        O      | O
# party            O      | O
# required         O      | O
# receive          O      | O
# notice           O      | O
# communication    O      | O
# address          O      | O
# set              O      | O
# borrower         I-PER  | I-PER
# usine            O      | O
# de               O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# page             O      | O
# december         O      | O
# saint            I-LOC  | I-LOC
# auban            I-LOC  | O
# france           I-LOC  | I-LOC
# attention        O      | O
# frank            I-PER  | I-PER
# wouters          I-PER  | O
# ceo              I-LOC  | O
# lender           I-PER  | I-PER
# bartlett         I-LOC  | I-LOC
# street           I-LOC  | I-LOC
# marlboro         I-LOC  | I-ORG
# massachusetts    I-LOC  | I-LOC
# attention        O      | O
# richard          I-PER  | I-PER
# chleboski        I-PER  | I-ORG
# vice             O      | O
# president        O      | O
# address          O      | O
# relevant         O      | O
# party            O      | O
# may              O      | O
# specify          O      | O
# notice           O      | O
# writing          O      | O
# parties          O      | O
# notice           O      | O
# communication    O      | O
# sent             O      | O
# mail             O      | O
# facsimile        O      | O
# must             O      | O
# confirmed        O      | O
# commercial       O      | O
# courier          O      | O
# notice           O      | O
# communication    O      | O
# deemed           O      | O
# duly             O      | O
# given            O      | O
# delivered        O      | O
# personally       O      | O
# left             O      | O
# address          O      | O
# referred         O      | O
# article          O      | O
# delivered        O      | O
# commercial       O      | O
# courier          O      | O
# date             O      | O
# signature        O      | O
# courier          O      | O
# receipt          O      | O
# sent             O      | O
# fax              O      | O
# time             O      | O
# transmission     O      | O
# sent             O      | O
# mail             O      | O
# time             O      | O
# despatch         O      | O
# deemed           O      | O
# receipt          O      | O
# previous         O      | O
# paragraphs       O      | O
# article          O      | O
# within           O      | O
# business         O      | O
# hours            O      | O
# meaning          O      | O
# pm               O      | O
# monday           O      | O
# friday           O      | O
# day              O      | O
# public           O      | O
# holiday          O      | O
# place            O      | O
# receipt          O      | O
# business         O      | O
# next             O      | O
# starts           O      | O
# place            O      | O
# receipt          O      | O
# confidentiality  O      | O
# party            O      | O
# undertakes       O      | O
# time             O      | O
# loan             O      | O
# agreement        O      | O
# period           O      | O
# five             O      | O
# years            O      | O
# termination      O      | O
# loan             O      | O
# agreement        O      | O
# disclose         O      | O
# person           O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# article          O      | O
# means            O      | O
# knowledge        O      | O
# financial        O      | O
# data             O      | O
# operating        O      | O
# data             O      | O
# trade            O      | O
# secrets          O      | O
# experience       O      | O
# know             O      | O
# information      O      | O
# kinds            O      | O
# whatever         O      | O
# form             O      | O
# technologies     O      | I-ORG
# finances         O      | O
# costs            O      | O
# marketing        O      | O
# business         O      | O
# including        O      | O
# limited          O      | O
# term             O      | O
# sheets           O      | O
# notes            O      | O
# analyses         O      | O
# agreements       O      | O
# compilations     O      | O
# studies          O      | O
# interpretations  O      | O
# suchlike         O      | O
# disclosed        O      | O
# behalf           O      | O
# disclosing       O      | O
# party            O      | O
# whether          O      | O
# marked           O      | O
# confidential     O      | O
# information      O      | O
# including        O      | O
# confidential     O      | O
# information      O      | O
# communicated     O      | O
# receiving        O      | O
# party            O      | O
# orally           O      | O
# reduced          O      | O
# writing          O      | O
# exclude          O      | O
# information      O      | O
# becomes          O      | O
# improper         O      | O
# action           O      | O
# inaction         O      | O
# receiving        O      | O
# party            O      | O
# affiliate        O      | O
# agent            O      | O
# consultant       O      | O
# employee         O      | O
# generally        O      | O
# available        O      | O
# public           O      | O
# ii               O      | O
# possession       O      | O
# known            O      | O
# prior            O      | O
# receipt          O      | O
# disclosing       O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iii              O      | O
# rightfully       O      | O
# disclosed        O      | O
# third            O      | O
# party            O      | O
# provided         O      | O
# receiving        O      | O
# party            O      | O
# complies         O      | O
# restrictions     O      | O
# imposed          O      | O
# thereon          O      | O
# third            O      | O
# parties          O      | O
# iv               O      | O
# independently    O      | O
# developed        O      | O
# without          O      | O
# use              O      | O
# confidential     O      | O
# information      O      | O
# disclosing       O      | O
# party            O      | O
# ôøω              O      | O
# party            O      | O
# may              O      | O
# disclose         O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# page             O      | O
# december         O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# need             O      | O
# know             O      | O
# information      O      | O
# purposes         O      | O
# carrying         O      | O
# party            O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# party            O      | O
# ensure           O      | O
# employees        O      | O
# officers         O      | O
# representatives  O      | O
# advisers         O      | O
# discloses        O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# comply           O      | O
# article          O      | O
# may              O      | O
# required         O      | O
# law              O      | O
# court            O      | O
# order            O      | O
# governmental     O      | O
# regulatory       O      | O
# authority        O      | O
# party            O      | O
# use              O      | O
# party            O      | O
# confidential     O      | O
# information      O      | O
# purpose          O      | O
# perform          O      | O
# obligations      O      | O
# loan             O      | O
# agreement        O      | O
# applicable       O      | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# french           O      | O
# law              O      | O
# language         O      | O
# agreement        O      | O
# correspondence   O      | O
# notices          O      | O
# written          O      | O
# communications   O      | O
# english          O      | O
# disputes         O      | O
# dispute          O      | O
# arises           O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# directors        O      | O
# senior           O      | O
# representatives  O      | O
# parties          O      | O
# authority        O      | O
# settle           O      | O
# dispute          O      | O
# will             O      | O
# within           O      | O
# ten              O      | O
# days             O      | O
# written          O      | O
# request          O      | O
# one              O      | O
# party            O      | O
# meet             O      | O
# good             O      | O
# faith            O      | O
# effort           O      | O
# resolve          O      | O
# dispute          O      | O
# disputes         O      | O
# arising          O      | O
# connection       O      | O
# loan             O      | O
# agreement        O      | O
# resolved         O      | O
# pursuant         O      | O
# article          O      | O
# finally          O      | O
# settled          O      | O
# rules            O      | O
# arbitration      O      | O
# international    O      | I-ORG
# chamber          O      | O
# commerce         O      | O
# three            O      | O
# arbitrators      O      | O
# appointed        O      | O
# accordance       O      | O
# said             O      | O
# rules            O      | O
# arbitration      O      | O
# conducted        O      | O
# english          O      | O
# seat             O      | O
# paris            I-LOC  | I-LOC
# events           O      | O
# default          O      | O
# following        O      | O
# events           O      | O
# considered       O      | O
# events           O      | O
# default          O      | O
# respect          O      | O
# loan             O      | O
# agreement        O      | O
# borrower         I-PER  | I-PER
# default          O      | O
# payment          O      | O
# part             O      | O
# principal        O      | O
# unpaid           O      | O
# accrued          O      | O
# interest         O      | O
# loan             O      | O
# thirty           O      | O
# days             O      | O
# become           O      | O
# due              O      | O
# payable          O      | O
# whether          O      | O
# maturity         O      | O
# date             O      | O
# fixed            O      | O
# prepayment       O      | O
# acceleration     O      | O
# borrower         I-PER  | I-PER
# unable           O      | O
# admits           O      | O
# inability        O      | O
# pay              O      | O
# debts            O      | O
# fall             O      | O
# due              O      | O
# reason           O      | O
# actual           O      | O
# anticipated      O      | O
# financial        O      | O
# difficulties     O      | O
# suspends         O      | O
# making           O      | O
# payments         O      | O
# debts            O      | O
# commences        O      | O
# negotiations     O      | O
# one              O      | O
# creditors        O      | O
# view             O      | O
# rescheduling     O      | O
# indebtedness     O      | O
# borrower         I-PER  | I-PER
# state            O      | O
# suspension       O      | O
# payments         O      | O
# cessation        O      | O
# des              O      | O
# paiements        O      | O
# within           O      | O
# meaning          O      | O
# article          O      | O
# french           O      | O
# commercial       O      | O
# code             O      | O
# corporate        O      | O
# action           O      | O
# legal            O      | O
# proceedings      O      | O
# procedures       O      | O
# steps            O      | O
# taken            O      | O
# reason           O      | O
# borrower         I-PER  | I-PER
# financial        O      | O
# difficulties     O      | O
# relation         O      | O
# suspension       O      | O
# payments         O      | O
# moratorium       O      | O
# indebtedness     O      | O
# winding          O      | O
# dissolution      O      | O
# administration   O      | O
# reorganisation   O      | O
# solvent          O      | O
# winding          O      | O
# dissolution      O      | O
# reorganisation   O      | O
# carried          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# lender           I-PER  | I-PER
# consent          O      | O
# unreasonably     O      | O
# withheld         O      | O
# delayed          O      | O
# borrower         I-PER  | I-PER
# composition      O      | O
# compromise       O      | O
# assignment       O      | O
# arrangement      O      | O
# creditor         O      | O
# borrower         I-PER  | I-PER
# page             O      | O
# december         O      | O
# appointment      O      | O
# liquidator       O      | O
# receiver         O      | O
# administrator    O      | O
# administrative   O      | O
# receiver         O      | O
# compulsory       O      | O
# manager          O      | O
# similar          O      | O
# officer          O      | O
# respect          O      | O
# borrower         I-PER  | I-PER
# assets           O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# commences        O      | O
# proceedings      O      | O
# conciliation     O      | O
# accordance       O      | O
# articles         O      | O
# french           O      | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# procedure        O      | O
# step             O      | O
# taken            O      | O
# jurisdiction     O      | O
# judgment         O      | O
# sauvegarde       O      | O
# redressement     O      | O
# judiciaire       O      | O
# liquidation      O      | O
# judiciaire       O      | O
# entered          O      | O
# relation         O      | O
# borrower         I-PER  | I-PER
# articles         O      | O
# french           O      | O
# commercial       O      | O
# code             O      | O
# analogous        O      | O
# judgment         O      | O
# entered          O      | O
# jurisdiction     O      | O
# borrower         I-PER  | I-PER
# fail             O      | O
# observe          O      | O
# perform          O      | O
# obligation       O      | O
# observed         O      | O
# performed        O      | O
# loan             O      | O
# agreement        O      | O
# within           O      | O
# thirty           O      | O
# days             O      | O
# written          O      | O
# notice           O      | O
# lender           I-PER  | I-PER
# perform          O      | O
# observe          O      | O
# obligation       O      | O
# borrower         I-PER  | I-PER
# stops            O      | O
# construction     O      | O
# works            O      | O
# acknowledges     O      | O
# will             O      | O
# unable           O      | O
# unwilling        O      | O
# complete         O      | O
# ...
# holder           O      | O
# agent            O      | O
# service          O      | O
# process          O      | O
# entries          O      | O
# register         O      | O
# conclusive       O      | O
# binding          O      | O
# purposes         O      | O
# absent           O      | O
# manifest         O      | O
# error            O      | O
# servicer         O      | O
# holders          O      | O
# may              O      | O
# treat            O      | O
# person           O      | O
# entity           O      | O
# whose            O      | O
# name             O      | O
# recorded         O      | O
# register         O      | O
# holder           O      | O
# hereunder        O      | O
# purposes         O      | O
# agreement        O      | O
# register         O      | O
# available        O      | O
# inspection       O      | O
# copying          O      | O
# holder           O      | O
# normal           O      | O
# business         O      | O
# hours            O      | O
# upon             O      | O
# reasonable       O      | O
# prior            O      | O
# notice           O      | O
# servicer         O      | O
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# hereto           O      | O
# caused           O      | O
# agreement        O      | O
# duly             O      | O
# executed         O      | O
# day              O      | O
# year             O      | O
# first            O      | O
# written          O      | O
# pim              O      | I-PER
# ashford          I-ORG  | I-LOC
# venture          I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# investments      O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# prisa            O      | O
# iii              O      | O
# reit             O      | O
# operating        O      | O
# lp               O      | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# sole             O      | O
# member           O      | O
# prisa            O      | O
# iii              O      | O
# op               O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# lp               O      | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# manager          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# gp               O      | O
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# prisa            O      | O
# iii              O      | O
# fund             O      | O
# pim              O      | I-PER
# llc              O      | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# sole             O      | O
# member           O      | O
# prudential       O      | O
# investment       O      | O
# management       O      | O
# inc              O      | O
# delaware         O      | O
# corporation      O      | O
# sole             O      | O
# member           O      | O
# name             O      | O
# james            I-PER  | I-LOC
# walker           O      | I-PER
# title            O      | O
# vice             O      | O
# president        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | O
# finance          I-ORG  | O
# lp               I-ORG  | O
# delaware         O      | O
# limited          O      | O
# partnership      O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | O
# finance          I-ORG  | O
# general          I-ORG  | O
# partner          I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# general          O      | O
# partner          O      | O
# name             O      | O
# david            I-PER  | I-PER
# brooks           I-PER  | I-PER
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# ashford          I-ORG  | I-LOC
# hospitality      I-ORG  | O
# servicing        I-ORG  | O
# llc              I-ORG  | O
# delaware         O      | O
# limited          O      | O
# liability        O      | O
# company          O      | O
# name             O      | O
# david            I-PER  | I-PER
# brooks           I-PER  | I-PER
# title            O      | O
# vice             O      | O
# president        O      | O
# signature        O      | O
# page             O      | O
# loan             O      | O
# servicing        O      | O
# agreement        O      | O
# schedule         O      | O
# loan             O      | O
# documents        O      | O
# source           O      | O
# onecle           O      | I-PER
# business         O      | O
# contracts        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# crocs            O      | O
# inc              O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# logo             O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# amendment        O      | O
# loan             O      | O
# agreement        O      | O
# dated            O      | O
# november         O      | O
# entered          O      | O
# among            O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# loan             O      | O
# agreement        O      | O
# twenty           O      | O
# five             O      | O
# million          O      | O
# dollars          O      | O
# words            O      | O
# add              O      | O
# minimum          O      | O
# net              O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# covenant         O      | O
# section          O      | O
# loan             O      | O
# agreement        O      | O
# hereby           O      | O
# added            O      | O
# read             O      | O
# full             O      | O
# follows          O      | O
# domestic         O      | O
# accounts         O      | O
# receivable       O      | O
# conditions       O      | O
# precedent        O      | O
# effectiveness    O      | O
# amendment        O      | O
# subject          O      | O
# prior            O      | O
# satisfaction     O      | O
# following        O      | O
# conditions       O      | O
# amendment        O      | O
# bank             I-ORG  | I-ORG
# received         O      | O
# original         O      | O
# amendment        O      | O
# duly             O      | O
# executed         O      | O
# borrower         I-PER  | I-PER
# bank             I-ORG  | I-ORG
# documents        O      | O
# borrower         I-PER  | I-PER
# executed         O      | O
# delivered        O      | O
# bank             I-ORG  | I-ORG
# revolving        O      | O
# note             O      | O
# documents        O      | O
# instruments      O      | O
# bank             I-ORG  | I-ORG
# may              O      | O
# reasonably       O      | O
# require          O      | O
# miscellaneous    O      | O
# survival         O      | O
# representations  O      | O
# warranties       O      | O
# representations  O      | O
# warranties       O      | O
# made             O      | O
# loan             O      | O
# agreement        O      | O
# document         O      | O
# documents        O      | O
# relating         O      | O
# thereto          O      | O
# including        O      | O
# without          O      | O
# limitation       O      | O
# loan             O      | O
# documents        O      | O
# furnished        O      | O
# connection       O      | O
# amendment        O      | O
# survive          O      | O
# execution        O      | O
# delivery         O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# investigation    O      | O
# bank             I-ORG  | I-ORG
# closing          O      | O
# affect           O      | O
# representations  O      | O
# warranties       O      | O
# right            O      | O
# bank             I-ORG  | I-ORG
# rely             O      | O
# thereon          O      | O
# events           O      | O
# default          O      | O
# borrower         I-PER  | I-PER
# aware            O      | O
# events           O      | O
# now              O      | O
# constitute       O      | O
# passage          O      | O
# time             O      | O
# giving           O      | O
# notice           O      | O
# constitute       O      | O
# event            O      | O
# default          O      | O
# loan             O      | O
# agreement        O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# agreements       O      | O
# documents        O      | O
# instruments      O      | O
# now              O      | O
# hereafter        O      | O
# executed         O      | O
# delivered        O      | O
# pursuant         O      | O
# terms            O      | O
# hereof           O      | O
# pursuant         O      | O
# terms            O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# hereby           O      | O
# amended          O      | O
# reference        O      | O
# therein          O      | O
# loan             O      | O
# agreement        O      | O
# mean             O      | O
# reference        O      | O
# loan             O      | O
# agreement        O      | O
# amended          O      | O
# hereby           O      | O
# loan             O      | O
# agreement        O      | O
# remains          O      | O
# effect           O      | O
# loan             O      | O
# agreement        O      | O
# loan             O      | O
# documents        O      | O
# remain           O      | O
# full             O      | O
# force            O      | O
# effect           O      | O
# borrower         I-PER  | I-PER
# ratifies         O      | O
# confirms         O      | O
# agreements       O      | O
# covenants        O      | O
# contained        O      | O
# therein          O      | O
# borrower         I-PER  | I-PER
# hereby           O      | O
# confirms         O      | O
# giving           O      | O
# effect           O      | O
# amendment        O      | O
# event            O      | O
# default          O      | O
# default          O      | O
# exists           O      | O
# date             O      | O
# severability     O      | O
# provision        O      | O
# amendment        O      | O
# held             O      | O
# court            O      | O
# competent        O      | O
# jurisdiction     O      | O
# invalid          O      | O
# unenforceable    O      | O
# impair           O      | O
# invalidate       O      | O
# remainder        O      | O
# amendment        O      | O
# effect           O      | O
# thereof          O      | O
# confined         O      | O
# provision        O      | O
# held             O      | O
# invalid          O      | O
# unenforceable    O      | O
# applicable       O      | O
# law              O      | O
# amendment        O      | O
# loan             O      | O
# documents        O      | O
# executed         O      | O
# pursuant         O      | O
# hereto           O      | O
# deemed           O      | O
# made             O      | O
# performable      O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# governed         O      | O
# construed        O      | O
# accordance       O      | O
# laws             O      | O
# state            O      | O
# california       I-LOC  | I-LOC
# successors       O      | O
# assigns          O      | O
# amendment        O      | O
# binding          O      | O
# upon             O      | O
# inure            O      | O
# benefit          O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# respective       O      | O
# successors       O      | O
# assigns          O      | O
# provided         O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# assign           O      | O
# transfer         O      | O
# rights           O      | O
# obligations      O      | O
# hereunder        O      | O
# without          O      | O
# prior            O      | O
# written          O      | O
# consent          O      | O
# bank             I-ORG  | I-ORG
# counterparts     O      | O
# amendment        O      | O
# may              O      | O
# executed         O      | O
# one              O      | O
# counterparts     O      | O
# executed         O      | O
# deemed           O      | O
# original         O      | O
# taken            O      | O
# together         O      | O
# constitute       O      | O
# one              O      | O
# instrument       O      | O
# headings         O      | O
# headings         O      | O
# captions         O      | O
# arrangements     O      | O
# used             O      | O
# amendment        O      | O
# convenience      O      | O
# affect           O      | O
# interpretation   O      | O
# amendment        O      | O
# oral             O      | O
# agreements       O      | O
# amendment        O      | O
# together         O      | O
# loan             O      | O
# documents        O      | O
# written          O      | O
# represents       O      | O
# final            O      | O
# agreement        O      | O
# lenders          O      | O
# borrower         I-PER  | I-PER
# may              O      | O
# contradicted     O      | O
# evidence         O      | O
# prior            O      | O
# contemporaneous  O      | O
# subsequent       O      | O
# oral             O      | O
# agreements       O      | O
# parties          O      | O
# unwritten        O      | O
# oral             O      | O
# agreements       O      | O
# bank             I-ORG  | I-ORG
# borrower         I-PER  | I-PER
# witness          O      | O
# whereof          O      | O
# parties          O      | O
# entered          O      | O
# amendment        O      | O
# respective       O      | O
# duly             O      | O
# authorized       O      | O
# officers         O      | O
# date             O      | O
# first            O      | O
# written          O      | O
# crocs            O      | O
# inc              O      | O
# peter            I-PER  | O
# case             I-PER  | O
# peter            I-PER  | O
# case             I-PER  | O
# title            O      | O
# chief            O      | O
# financial        O      | O
# officer          O      | O
# address          O      | O
# monarch          I-LOC  | O
# park             I-LOC  | I-LOC
# place            I-LOC  | O
# niwot            I-LOC  | I-ORG
# colorado         I-LOC  | I-LOC
# attention        O      | O
# keith            I-PER  | I-PER
# love             I-PER  | O
# treasury         O      | O
# manager          O      | O
# telecopier       O      | O
# telephone        O      | O
# union            I-ORG  | O
# bank             I-ORG  | I-ORG
# california       I-LOC  | I-LOC
# douglas          I-PER  | I-LOC
# lambell          O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# title            O      | O
# vice             O      | O
# president        O      | O
# address          O      | O
# street           I-LOC  | I-LOC
# floor            I-LOC  | I-LOC
# san              I-LOC  | I-LOC
# diego            I-LOC  | O
# california       I-LOC  | I-LOC
# attention        O      | O
# douglas          I-PER  | I-LOC
# lambell          O      | O
# vp               O      | O
# telecopier       O      | O
# telephone        O      | O
# source           O      | O
# onecle           O      | I-PER
# business         O      | O
# contracts        O      | O

# %%
plot_history(history)

# %% [markdown]
# The high training accuracy of about 0.99 and the low training loss of around 0.03 show that the model is learning well from the training data, making accurate predictions.
# With a validation accuracy of 0.985, the model demonstrates strong generalization capabilities to new, unseen data. The validation loss remains at an acceptable level, suggesting minimal risk of overfitting.

# %%
print(classification_report(y_true_nomisc, y_pred_nomisc))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      0.99      0.99      4555
#            1       0.54      0.62      0.58        61
#            2       0.45      0.27      0.34        97
#            3       0.93      0.90      0.91       192
#
#     accuracy                           0.97      4905
#    macro avg       0.72      0.70      0.70      4905
# weighted avg       0.96      0.97      0.97      4905

# %% [markdown]
# The classification report reveals varied performance across different named entity categories. It provides an overall accuracy of the model of 97%. The model excels in predicting **O** and **I-PER** entities, with a high precision, recall, and F1-score.

# %%
cf_matrix = confusion_matrix(y_true_nomisc, y_pred_nomisc, normalize = "true")

# %%
def plot_confusion_matrix_nomisc(y_preds, y_test):
    fig, ax = plt.subplots(figsize=(6, 6))
    disp = ConfusionMatrixDisplay(confusion_matrix=cf_matrix, display_labels=ner_labels_nomisc)
    disp.plot(cmap="BuPu", values_format=".2f", ax=ax, colorbar=False)
    plt.title("Normalized confusion matrix")
    ax.grid(False)
    plt.show()

# %%
plot_confusion_matrix_nomisc(y_pred_nomisc, y_true_nomisc)

# %% [markdown]
# From the matrix strong diagonal elements can be observed, especially for the **O** and **I-PER**, suggesting that the model performance in identifying **O** and **I-PER** NER tags is robust.
# \
# However, the performance is less pronounced for **I-ORG** and **I-LOC**, as indicated from off-diagonal elements.

# %% [markdown]
# # BERT

# %% [markdown]
# BERT (Bidirectional Encoder Representations from Transformers) model incorporates a bidirectional attention mechanism, allowing it to consider context from both left and right directions in a sequence, deviating from sequential models.

# %% [markdown]
# ## Load data

# %% [markdown]
# The response variable in the training, validation and test is transformed from a vector to an integer. This conversion, achieved through the *argmax* function, establishes a numerical representation for the categories of the response variable in each dataset.

# %%
nerid_train = np.argmax(y_train, axis = 1)
nerid_valid = np.argmax(y_valid, axis = 1)
nerid_test = np.argmax(y_test, axis = 1)

# %% [markdown]
# It is now created *DatasetDict* structured to contain three key elements: *train*, *validation*, and *test*. Each of these elements holds a dataset as text and corresponding indices. This organization facilitates the subsequent model training phase, allowing easy access to the required datasets during the training process.

# %%
# %%capture
# !pip install datasets
from datasets import Dataset, DatasetDict

# %%
train_dataset = Dataset.from_dict({"text": raw_train, "label": nerid_train})
validation_dataset = Dataset.from_dict({"text": raw_valid, "label": nerid_valid})
test_dataset = Dataset.from_dict({"text": raw_test, "label": nerid_test})

data_dict = DatasetDict({
    "train": train_dataset,
    "validation": validation_dataset,
    "test": test_dataset
})
data_dict
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label'],
#         num_rows: 14319
#     })
#     validation: Dataset({
#         features: ['text', 'label'],
#         num_rows: 3580
#     })
#     test: Dataset({
#         features: ['text', 'label'],
#         num_rows: 4905
#     })
# })

# %% [markdown]
# The chosen model checkpoint, *distilbert-base-uncased*, is loaded using the *Hugging Face Transformers* library. It represents a distilled version of the *BERT* model, tailored for case-insensitive text processing tasks. The *AutoTokenizer* class is utilized to automatically select and load the appropriate tokenizer for this model checkpoint, ensuring compatibility with its architecture.
#
# The function *tokenize* is applied to the entire dataset. This function uses the loaded tokenizer to process batches of text data, implementing padding, truncation and the addition of special tokens as needed. This preprocessing step is crucial to prepare the data for subsequent training, ensuring it aligns with the requirements of the *BERT* model.

# %%
from transformers import AutoTokenizer

model_ckpt = "distilbert-base-uncased"
tokenizer = AutoTokenizer.from_pretrained(model_ckpt)

# %%
def tokenize(batch):
   return tokenizer(batch["text"],padding=False, truncation=True, add_special_tokens=False)

# %%
data4 = data_dict.map(tokenize, batched=True, batch_size=8)
# Out:
# Map:   0%|          | 0/14319 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3580 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4905 [00:00<?, ? examples/s]

# %% [markdown]
# ## Build the Transformer

# %% [markdown]
# The model undergoes the process of fine-tuning for sequence classification using the *Transformers* library.

# %%
import torch

# %% [markdown]
# The model selects the *distilbert-base-uncased* checkpoint, which serves as a robust foundation for the task at hand.

# %%
# %%capture
from transformers import AutoModelForSequenceClassification

model_ckpt = "distilbert-base-uncased"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_labels = 5
model = (AutoModelForSequenceClassification
         .from_pretrained(model_ckpt, num_labels=num_labels)
         .to(device))

# %%
# To assess model's performance
# It calculates metrics like accuracy and F1 score during evaluation.
from sklearn.metrics import accuracy_score, f1_score

def compute_metrics(pred):
    labels = pred.label_ids
    preds = pred.predictions.argmax(-1)
    f1 = f1_score(labels, preds, average="weighted")
    acc = accuracy_score(labels, preds)
    return {"accuracy": acc, "f1": f1}

# %%
# %%capture
#!pip install accelerate>=0.20.1

# %%
# Definition of training parameters and configurations for the fine-tuning process.
from transformers import Trainer, TrainingArguments

batch_size = 8
logging_steps = len(raw_train) // batch_size
model_name = f"{model_ckpt}-finetuned-emotion"
training_args = TrainingArguments(output_dir=model_name,
                                  num_train_epochs=2,
                                  learning_rate=2e-5,
                                  per_device_train_batch_size=batch_size,
                                  per_device_eval_batch_size=batch_size,
                                  weight_decay=0.01,
                                  evaluation_strategy="epoch",
                                  disable_tqdm=False,
                                  logging_steps=logging_steps,
                                  push_to_hub=False,
                                  log_level="error")

# %% [markdown]
# The *Trainer* module is enlisted to orchestrate the training process. The *Trainer* takes charge of managing the training loop, evaluation steps, and other essential components. The model is fine-tuned using the training dataset (*data4["train"]*), and performance is evaluated on the validation dataset (*data4["validation"]*). The process is driven by the specified training arguments, ensuring a coherent and effective fine-tuning process for the NER classification task.

# %%
from transformers import Trainer

trainer = Trainer(model=model, args=training_args,
                  compute_metrics=compute_metrics,
                  train_dataset=data4["train"],
                  eval_dataset=data4["validation"],
                  tokenizer=tokenizer)

trainer.train();
# Out:
#     <div>
#
#       <progress value='3580' max='3580' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [3580/3580 04:05, Epoch 2/2]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.144500</td>
#       <td>0.088770</td>
#       <td>0.982682</td>
#       <td>0.981251</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.072200</td>
#       <td>0.076248</td>
#       <td>0.984637</td>
#       <td>0.983622</td>
#     </tr>
#   </tbody>
# </table><p>

# %% [markdown]
# Following the completion of the fine-tuning process, the model is applied to the test dataset using the *predict* method. This step involves making predictions on the test data to assess how well the model generalizes to new, unseen examples. The resulting `preds_output` contains predictions for each instance in the test dataset.

# %%
preds_output = trainer.predict(data4["test"])

# %%
preds_output.metrics
# Out:
# {'test_loss': 0.17145785689353943,
#  'test_accuracy': 0.963710499490316,
#  'test_f1': 0.9611230286386748,
#  'test_runtime': 5.6573,
#  'test_samples_per_second': 867.017,
#  'test_steps_per_second': 108.532}

# %% [markdown]
# The test accuracy of 96.4%  has demonstrated proficiency in classifying sequences into the correct categories.
# \
# Additionally, the F1 score, which combines precision and recall, is computed as 96% and it suggests that the model maintains a good balance between precision and recall, achieving robust performance across multiple classes.
# \
# The test loss, which measures the dissimilarity between the true labels and the predicted ones, is 17%. The relatively low test loss further supports the model's effectiveness in capturing patterns and relationships within the test dataset.

# %%
y_preds = np.argmax(preds_output.predictions, axis=1)
y_test = np.array(data4["test"]["label"])

# %%
plot_confusion_matrix(y_preds, y_valid, ner_labels)

# %% [markdown]
# From the matrix strong diagonal elements can be observed, especially for the **O** and the **I-PER** NER tags, indicating high correctness in predictions for these categories. However, off-diagonal elements reveal still areas where the model encounters challenges, particularly in the case of **I-MISC** and **I-LOC**.

# %% [markdown]
# # Comparison between models

# %% [markdown]
# The evaluation of four distinct models, each with varying configurations, reveals intriguing insights into their performance on the Named Entity Recognition (NER) task. All models consistently produce comparable accuracy, loss and F1-score results, demonstrating robust performance.
# \
# Despite the initial model yielding satisfactory results, the analysis of the confusion matrix revealed an oversight in predicting any instances of **I-MISC**. Subsequently, a second model was developed, incorporating `chunk_label` as an additional feature. However, although achieving excellent overall results, once again, no instances of **I-MISC** were predicted. As an improvement, the third model was devised, reclassifying **I-MISC** as **O**, resulting in a slight improvement and a minor increase in F1-score. This adjustment proved insightful in addressing the challenges posed by unbalanced datasets.
# \
# In addition, the BERT model demonstrated comparable accuracy, loss, and F1-score results with respect to the other models.
# \
# In conclusion, the consistent performance observed across diverse model architectures underscores the robustness of each approach, offering valuable insights for effectively handling unbalanced datasets.
